# %% [markdown]
# Question 1:Write a program to perform addition, subtraction, multiplication, division, floor division, modulus, and exponentiation on two numbers.

# %%
a = float(input("enter a number a:"))
b = float(input("enter a number b:"))
print("addition:",a+b)
print("subtraction:",a-b)
print("multilication:",a*b)
print("division:",a/b)
print("floor division:",a//b)
print("modulus:",a%b)
print("exponentiation:",a**b)
# Out:
# enter a number a:6
# enter a number b:3
# addition: 9.0
# subtraction: 3.0
# multilication: 18.0
# division: 2.0
# floor division: 2.0
# modulus: 0.0
# exponentiation: 216.0

# %% [markdown]
# Question 2: Swap two numbers without using a third variable.

# %%
a=int(input("enter a number a:"))
b=int(input("enter a number b:"))
a=a+b
b=a-b
a=a-b
print("after swapping:")
print("first number a:",a)
print("second number b=",b)
# Out:
# enter a number a:2
# enter a number b:4
# after swapping:
# first number a: 4
# second number b= 2

# %% [markdown]
# Question 3: Find whether a number is even or odd using the modulus operator.

# %%
number = int(input("enter a number"))
if number % 2 ==0:
  print(number, "is even")
else:
  print(number, "is odd")
# Out:
# enter a number4
# 4 is even

# %% [markdown]
# Question 4:Reverse a three-digit number using arithmetic operators.

# %%
a =int(input("enter a three digit number:"))
hundred = a//100
tens = (a//10)%10
onces = a%10
reversed = onces*100+tens*10+hundred
print("reversed number:",reversed)
# Out:
# enter a three digit number:213
# reversed number: 312

# %% [markdown]
# Qustion 5:Find the last digit and first digit of a given number.

# %%
a = int(input("enter a number"))
first_digit=a//10
last_digit =a%10
print("first_digit",first_digit)
print("last_digit",last_digit)
# Out:
# enter a number23
# first_digit 2
# last_digit 3

# %% [markdown]
# Question 6:Demonstrate all assignment operators (=, +=, -=, *=, /=, //=, %= and **=) on a variable.

# %%
x=5
print("initial value of x:", x)
x=20
print("after x=10:",x)
x+=5
print("after x+=5", x)
x-=5
print("after x-=5", x)
x*=2
print("after x*=2", x)
x/=5
print("after x/=5", x)
x//=5
print("after x//5", x)
x%=5
print("after x%=5", x)
x**=2
print("after x**=2", x)
# Out:
# initial value of x: 5
# after x=10: 20
# after x+=5 25
# after x-=5 20
# after x*=2 40
# after x/=5 8.0
# after x//5 1.0
# after x%=5 1.0
# after x**=2 1.0

# %% [markdown]
# Question 7: Update a bank account balance using compound assignment operators.

# %%
balance = 1000
print("Initial Balance =", balance)
balance += 2500
print("After Deposit (+2500):", balance)
balance -= 150
print("After Withdrawal (-1500):", balance)
balance *= 0.05
print("After 5% Interest:", balance)
balance /= 2
print("After Dividing Balance by 2:", balance)
balance //= 2
print("After Floor Division by 2:", balance)
balance %= 1000
print("Balance after Modulus 1000:", balance)
balance **= 2
print("Balance after Squaring:", balance)
# Out:
# Initial Balance = 1000
# After Deposit (+2500): 3500
# After Withdrawal (-1500): 3350
# After 5% Interest: 167.5
# After Dividing Balance by 2: 83.75
# After Floor Division by 2: 41.0
# Balance after Modulus 1000: 41.0
# Balance after Squaring: 1681.0

# %% [markdown]
# Question 8:Calculate the total marks using += inside a loop.

# %%
n = int(input("enter the number of subjects:"))
total =0
for i in range(n):
  marks=int(input(f"enter the marks for subject{i+1}:"))
  total += marks
print(f"total marks:",total)
# Out:
# enter the number of subjects:5
# enter the marks for subject1:80
# enter the marks for subject2:78
# enter the marks for subject3:67
# enter the marks for subject4:98
# enter the marks for subject5:68
# total marks: 391

# %% [markdown]
# Question 9:Compare two numbers and print the larger number.

# %%
a=int(input("enter a number a:"))
b=int(input("enter a number b:"))
if a>b:
  print("a is greater than b")
elif b>a:
  print("b is greater than a")
else :
  print("both are equal")
# Out:
# enter a number a:4
# enter a number b:6
# b is greater than a

# %% [markdown]
# Question 10:Check whether three numbers are equal.

# %%
a= int(input("enter a number a:"))
b=int(input("enter a number b:"))
c=int(input("enter a number c:"))
if a==b==c:
  print("all three number are equal")
else:
  print("there are not equal")
# Out:
# enter a number a:4
# enter a number b:3
# enter a number c:5
# there are not equal

# %% [markdown]
# Question 11:Find the largest among three numbers using comparison operators.

# %%
a=int(input("enter a number a:"))
b=int(input("enter a number b:"))
c=int(input("enter a number c:"))
if a>=b and a>=c:
  print("a is largest number")
elif b>=c and b>=a:
  print("b is largest number")
else:
  print("c is largest number")
# Out:
# enter a number a:43
# enter a number b:54
# enter a number c:3
# b is largest number

# %% [markdown]
# Question 12:Check whether a student is eligible to vote based on age.

# %%
age =int(input("enter the age student:"))
if age>=18:
  print("student is eligible to vote")
else:
  print("not eligible")
# Out:
# enter the age student:18
# student is eligible to vote

# %% [markdown]
# Question 13: Check if a person is eligible for a loan (age > 21 AND salary > 30000).

# %%
age = int(input("enter the age:"))
salary = int(input("enter the salary:"))
if age>21 and salary>30000:
  print("eligible for loan")
else:
  print("not eligible")
# Out:
# enter the age:22
# enter the salary:35000
# eligible for loan

# %% [markdown]
# Question 14:Check if a number lies between 10 and 100 using logical operators.

# %%
num = int(input("enter a number:"))
if num>=10 and num<=100:
  print("number lies between 10 and 100")
else:
  print("number not lies between 10 and 100")
# Out:
# enter a number:23
# number lies between 10 and 100

# %% [markdown]
# Question 15: Validate username and password using logical operators.

# %%
a=input("enter a password:")
b="abc@123"
if a==b:
  print("password is correct")
else:
  print("password is incorrect")
# Out:
# enter a password:abc@123
# password is correct

# %% [markdown]
# Question 16:Determine whether a year is a leap year using logical conditions.

# %%
a=int(input("enter a year:"))
if a%4==0 and a%100!=0 or a%400==0:
  print("leap year")
else:
  print("not leap year")
# Out:
# enter a year:2004
# leap year

# %% [markdown]
# Question 17: Find the bitwise AND, OR, XOR of two numbers.

# %%
a=int(input("enter a number a:"))
b=int(input("enter a number b:"))
print("bitwise and:",a&b)
print("bitwise or:",a|b)
print("bitwise xor:",a^b)
# Out:
# enter a number a:2
# enter a number b:4
# bitwise and: 0
# bitwise or: 6
# bitwise xor: 6

# %% [markdown]
# Question 18:Perform left shift and right shift operations.

# %%
a=int(input("enter a number a:"))
b=int(input("enter a number b:"))
print("left shift:",a<<b)
print("right shift:",a>>b)
# Out:
# enter a number a:4
# enter a number b:24
# left shift: 67108864
# right shift: 0

# %% [markdown]
# Question 19 : Check whether a number is even using a bitwise operator.

# %%
a=int(input("enter a number a:"))
if a&1==0:
  print("even")
else:
  print("odd")
# Out:
# enter a number a:7
# odd

# %% [markdown]
# Question 20:Swap two numbers using the XOR operator.

# %%
a=int(input("enter a number a:"))
b=int(input("enter a number b:"))
a=a^b
b=a^b
a=a^b
print("after swapping:")
print("first number a:",a)
print("second number b=",b)
# Out:
# enter a number a:2
# enter a number b:3
# after swapping:
# first number a: 3
# second number b= 2

# %% [markdown]
# Question 21:Count how many bits are set to 1 in a number using bitwise operations.

# %%
num = int(input("enter a number:"))
count = 0
while num:
  count += num & 1
  num >>= 1
print("number of set bits:",count)
# Out:
# enter a number:5
# number of set bits: 2

# %% [markdown]
# Question 22: Demonstrate the difference between is and ==.

# %%
a=[1,2,3,4]
b=[1,2,3,4]
print(a==b)
print(b is a)
# Out:
# True
# False

# %% [markdown]
# Question 23: Check whether two variables refer to the same list object.

# %%
list1 =[1,2,3,4]
list2=list1
list3=[1,2,3,4]
print(list1 is list2)
print(list1 is list3)
# Out:
# True
# False

# %% [markdown]
# Question 24:Show the behavior of is not with integers and lists.

# %%
a=10
b=20
print("a is not b:", a is not b)

list1=[1,2,3,4]
list2=[1,2,3,4]
print("list1 is not list2:",list1 is not list2)
# Out:
# a is not b: True
# list1 is not list2: True

# %% [markdown]
# Question 25: Check whether a character exists in a string.

# %%
a =input("enter a string:")
b=input("enter a character:")
if b in a:
  print("character exists in string")
else:
  print("character not exists in string")
# Out:
# enter a string:afgdsjfuye
# enter a character:f
# character exists in string

# %% [markdown]
# Question 26:Check whether a number exists in a list.

# %%
list =input("enter a list:")
a=input("enter a number:")
if a in list:
  print("number exists in list")
else:
  print("number not exists in list")
# Out:
# enter a list:2,3,4,5,6,0,7
# enter a number:3
# number exists in list

# %% [markdown]
# Question 27: Count how many vowels in a string belong to a predefined vowel list using in.

# %%
text = input("enter a string:")
vowels = "aeiouAEIOU"
count = 0
for char in text:
  if char in vowels:
    count += 1
print("number of vowels:",count)
# Out:
# enter a string:narayana
# number of vowels: 4

# %% [markdown]
# Question 28:Build a simple calculator using arithmetic and comparison operators.

# %%
a = float(input("enter a number a:"))
b = float(input("enter a number b:"))
print("addition:",a+b)
print("subtraction:",a-b)
print("multilication:",a*b)
print("division:",a/b)
print("floor division:",a//b)
print("modulus:",a%b)
print("exponentiation:",a**b)
print("a==b", a==b)
print("a>b", a>b)
print("a<b", a<b)
# Out:
# enter a number a:4
# enter a number b:2
# addition: 6.0
# subtraction: 2.0
# multilication: 8.0
# division: 2.0
# floor division: 2.0
# modulus: 0.0
# exponentiation: 16.0
# a==b False
# a>b True
# a<b False

# %% [markdown]
# Question 29:
# Create a grading system using comparison and logical operators.

# %%
marks = int(input("enter the marks"))
if marks>=90 and marks<=100:
  print("grade A")
elif marks>=80 and marks<90:
  print("grade B")
elif marks>=70 and marks<80:
  print("grade C")
  print("grade D")
elif marks>=60 and marks<70:
  print("grade E")
else:
  print("grade F")
# Out:
# enter the marks98
# grade A

# %%
Build a menu-driven calculator that uses arithmetic, comparison, logical, assignment, membership, identity, and bitwise operators wherever applicable.

# %% [markdown]
# Question 30:Build a menu-driven calculator that uses arithmetic, comparison, logical, assignment, membership, identity, and bitwise operators wherever applicable.

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

while True:
    print("menu")
    print("1. Arithmetic Operations")
    print("2. Comparison Operations")
    print("3. Logical Operations")
    print("4. Assignment Operation")
    print("5. Membership Operation")
    print("6. Identity Operation")
    print("7. Bitwise Operations")
    print("8. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        print("Addition:", num1 + num2)
        print("Subtraction:", num1 - num2)
        print("Multiplication:", num1 * num2)
        if num2 != 0:
            print("Division:", num1 / num2)
        else:
            print("Cannot divide by zero")

    elif choice == 2:
        print("num1 == num2:", num1 == num2)
        print("num1 > num2 :", num1 > num2)
        print("num1 < num2 :", num1 < num2)

    elif choice == 3:
        print("num1 > 0 and num2 > 0:", num1 > 0 and num2 > 0)
        print("num1 > 0 or num2 > 0 :", num1 > 0 or num2 > 0)
        print("not(num1 > num2):", not (num1 > num2))

    elif choice == 4:
        x = num1
        x += num2
        print("After x += num2:", x)

    elif choice == 5:
        lst = [10, 20, 30, 40]
        print("List:", lst)
        print("num1 in list:", num1 in lst)
        print("num2 not in list:", num2 not in lst)

    elif choice == 6:
        a = [1, 2, 3]
        b = a
        c = [1, 2, 3]
        print("a is b:", a is b)
        print("a is c:", a is c)

    elif choice == 7:
        print("Bitwise AND:", num1 & num2)
        print("Bitwise OR :", num1 | num2)
        print("Bitwise XOR:", num1 ^ num2)
        print("Left Shift :", num1 << 1)
        print("Right Shift:", num1 >> 1)

    elif choice == 8:
        print("Exiting Calculator...")
        break

    else:
        print("Invalid Choice!")
# Out:
# Enter first number: 1
# Enter second number: 23
# menu
# 1. Arithmetic Operations
# 2. Comparison Operations
# 3. Logical Operations
# 4. Assignment Operation
# 5. Membership Operation
# 6. Identity Operation
# 7. Bitwise Operations
# 8. Exit
# Enter your choice: 1
# Addition: 24
# Subtraction: -22
# Multiplication: 23
# Division: 0.043478260869565216
# menu
# 1. Arithmetic Operations
# 2. Comparison Operations
# 3. Logical Operations
# 4. Assignment Operation
# 5. Membership Operation
# 6. Identity Operation
# 7. Bitwise Operations
# 8. Exit
# Enter your choice: 2
# num1 == num2: False
# num1 > num2 : False
# num1 < num2 : True
# menu
# 1. Arithmetic Operations
# 2. Comparison Operations
# 3. Logical Operations
# 4. Assignment Operation
# 5. Membership Operation
# 6. Identity Operation
# 7. Bitwise Operations
# 8. Exit
# Enter your choice: 3
# num1 > 0 and num2 > 0: True
# num1 > 0 or num2 > 0 : True
# not(num1 > num2): True
# menu
# 1. Arithmetic Operations
# 2. Comparison Operations
# 3. Logical Operations
# 4. Assignment Operation
# 5. Membership Operation
# 6. Identity Operation
# 7. Bitwise Operations
# 8. Exit
# Enter your choice: 8
# Exiting Calculator...
