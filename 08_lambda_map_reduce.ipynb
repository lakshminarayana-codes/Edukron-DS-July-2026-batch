# %% [markdown]
# Question 1
# number = 8
# Write a lambda expression to calculate the square of number.

# %%
number = 8
square = lambda x: x ** 2
print(square(number))
# Out:
# 64

# %% [markdown]
# Question 2
# number = 5
# Write a lambda expression to calculate the cube of number.

# %%
number = 5
cube=lambda x:x**3
print(cube(number))
# Out:
# 125

# %% [markdown]
# Question 3
# a = 25
# b = 17
# Write a lambda expression to add a and b.

# %%
a=25
b=17
add = lambda a,b:a+b
print(add(a,b))
# Out:
# 42

# %% [markdown]
# Question 4
# a = 50
# b = 18
# Write a lambda expression to subtract b from a.

# %%
a=50
b=18
sub = lambda a,b:a-b
print(sub(a,b))
# Out:
# 32

# %% [markdown]
# Question 5
# a = 12
# b = 9
# Write a lambda expression to multiply a and b.

# %%
a=12
b=9
mul = lambda a,b:a*b
print(mul(a,b))
# Out:
# 108

# %% [markdown]
# Question 6
# a = 100
# b = 4
# Write a lambda expression to divide a by b.

# %%
a=100
b=4
div = lambda a,b:a/b
print(div(a,b))

# %% [markdown]
# Question 7
# a = 72
# b = 91
# Write a lambda expression to return the larger number.

# %%
a=72
b=91
larger = lambda a,b:max(a,b)
print(larger(a,b))
# Out:
# 91

# %% [markdown]
# Question 8
# a = 46
# b = 28
# Write a lambda expression to return the smaller number.

# %%
a=46
b=28
smaller = lambda a,b:min(a,b)
print(smaller(a,b))

# %% [markdown]
# Question 9
# number = 34
# Write a lambda expression that returns True when the number is even and False otherwise.

# %%
number = 34
even = lambda x:x%2==0
print(even(number))

# %% [markdown]
# Question 10
# number = 27
# Write a lambda expression that returns True when the number is odd and False otherwise.

# %%
number=27
odd = lambda x:x%2!=0
print(odd(number))
# Out:
# True

# %% [markdown]
# Question 11
# length = 12
# width = 8
# Write a lambda expression to calculate the area of a rectangle.

# %%
length =12
width = 8
area = lambda length,width:length*width
print(area(length,width))
# Out:
# 96

# %% [markdown]
# Question 12
# radius = 7
# Write a lambda expression to calculate the area of a circle using 3.14.

# %%
radius = 7
area = lambda radius:3.14*radius**2
print(area(radius))

# %% [markdown]
# Question 13
# length = 15
# width = 10
# Write a lambda expression to calculate the perimeter of a rectangle.

# %%
length = 15
width = 10
perimeter = lambda length,width:2*(length+width)
print(perimeter(length,width))

# %% [markdown]
# Question 14
# celsius = 35
# Write a lambda expression to convert Celsius into Fahrenheit.

# %%
celsius = 35
fahrenheit = lambda celsius:(celsius*9/5)+32
print(fahrenheit(celsius))

# %% [markdown]
# Question 15
# fahrenheit = 104
# Write a lambda expression to convert Fahrenheit into Celsius.

# %%
fahrenheit = 104
celsius = lambda fahrenheit:(fahrenheit-32)*5/9
print(celsius(fahrenheit))

# %% [markdown]
# Question 16
# word = "Python"
# Write a lambda expression to return the length of the string.

# %%
word = "Python"
length = lambda word:len(word)
print(length(word))
# Out:
# 6

# %% [markdown]
# Question 17
# word = "Azure"
# Write a lambda expression to return the first character of the string.

# %%
word = "Azure"
first_char = lambda word:word[0]
print(first_char(word))
# Out:
# A

# %% [markdown]
# Question 18
# word = "Databricks"
# Write a lambda expression to return the last character of the string.

# %%
word ="Databricks"
last_char = lambda word:word[-1]
print(last_char(word))
# Out:
# s

# %% [markdown]
# Question 19
# number = -45
# Write a lambda expression to return the absolute value of the number without using abs().

# %%
number =-46
absolute = lambda number:-number if number<0 else number
print(absolute(number))

# %% [markdown]
# Question 20
# marks = 72
# Write a lambda expression that returns:
#
# "Distinction" when marks are 75 or above
# "Pass" when marks are 40 to 74
# "Fail" when marks are below 40

# %%
marks = 72
result = lambda marks:"Distinction" if marks>=75 else "Pass" if marks>=40 else "Fail"
print(result(marks))
# Out:
# Pass

# %% [markdown]
# Section 2: map() — 20 Questions

# %% [markdown]
# Question 1 numbers = [1, 2, 3, 4, 5, 6] Using map() and a lambda expression, calculate the square of every number.

# %%
numbers = [1, 2, 3, 4, 5, 6]
square = list(map(lambda x:x**2,numbers))
print(square)
# Out:
# [1, 4, 9, 16, 25, 36]

# %% [markdown]
# Question 2 numbers = [2, 3, 4, 5, 6] Using map() and a lambda expression, calculate the cube of every number.

# %%
numbers = [2, 3, 4, 5, 6]
cube = list(map(lambda x:x**3,numbers))
print(cube)
# Out:
# [8, 27, 64, 125, 216]

# %% [markdown]
# Question 3 numbers = [10, 20, 30, 40, 50] Using map(), add 5 to every number.

# %%
numbers = [10, 20, 30, 40, 50]
add = list(map(lambda x:x+5,numbers))
print(add)
# Out:
# [15, 25, 35, 45, 55]

# %% [markdown]
# Question 4 numbers = [15, 25, 35, 45, 55] Using map(), subtract 10 from every number

# %%
numbers = [15, 25, 35, 45, 55]
sub = list(map(lambda x:x-10,numbers))
print(sub)
# Out:
# [5, 15, 25, 35, 45]

# %% [markdown]
# Question 5 numbers = [1, 5, 10, 15, 20] Using map(), multiply every number by 100.

# %%
numbers = [1,5,10,15,20]
mul = list(map(lambda x:x*100,numbers))
print(mul)
# Out:
# [100, 500, 1000, 1500, 2000]

# %% [markdown]
# Question 6 names = ["ravi", "anil", "meena", "kiran", "sneha"] Using map(), convert every name to uppercase.

# %%
names = ["ravi", "anil", "meena", "kiran", "sneha"]
upper = list(map(lambda x:x.upper(),names))
print(upper)
# Out:
# ['RAVI', 'ANIL', 'MEENA', 'KIRAN', 'SNEHA']

# %% [markdown]
# Question 7 names = ["RAHUL", "DIVYA", "ARJUN", "AJAY"] Using map(), convert every name to lowercase.

# %%
names = ["RAHUL", "DIVYA", "ARJUN", "AJAY"]
lower = list(map(lambda x:x.lower(),names))
print(lower)
# Out:
# ['rahul', 'divya', 'arjun', 'ajay']

# %% [markdown]
# Question 8 names = ["rahul kumar", "anil sharma", "meena reddy", "divya singh"] Using map(), convert every name to title case.

# %%
names = ["rahul kumar", "anil sharma", "meena reddy", "divya singh"]
title = list(map(lambda x:x.title(),names))
print(title)
# Out:
# ['Rahul Kumar', 'Anil Sharma', 'Meena Reddy', 'Divya Singh']

# %% [markdown]
# Question 9 words = ["Python", "Azure", "Databricks", "Cloud", "AI"] Using map(), calculate the length of every word.

# %%
words = ["Python", "Azure", "Databricks", "Cloud", "AI"]
length = list(map(lambda x:len(x),words))
print(length)
# Out:
# [6, 5, 10, 5, 2]

# %% [markdown]
# Question 10 words = ["Python", "Azure", "Docker", "Linux", "Spark"] Using map(), extract the first character of every word.

# %%
words = ["Python", "Azure", "Docker", "Linux", "Spark"]
first_char = list(map(lambda x:x[0],words))
print(first_char)
# Out:
# ['P', 'A', 'D', 'L', 'S']

# %% [markdown]
# Question 11 words = ["Python", "Azure", "Docker", "Linux", "Spark"] Using map(), extract the last character of every word.

# %%
words = ["Python", "Azure", "Docker", "Linux", "Spark"]
last_char = list(map(lambda x:x[-1],words))
print(last_char)
# Out:
# ['n', 'e', 'r', 'x', 'k']

# %% [markdown]
# Question 12 temperatures = [0, 10, 20, 30, 40] Using map(), convert every Celsius temperature into Fahrenheit.

# %%
temperatures = [0, 10, 20, 30, 40]
fahrenheit = list(map(lambda x:(x*9/5)+32,temperatures))
print(fahrenheit)
# Out:
# [32.0, 50.0, 68.0, 86.0, 104.0]

# %% [markdown]
# Question 13 prices = [100, 250, 500, 1000, 2500] Using map(), calculate 18% GST for every price.

# %%
prices = [100, 250, 500, 1000, 2500]
Gst = list(map(lambda x:x*0.18,prices))
print(Gst)
# Out:
# [18.0, 45.0, 90.0, 180.0, 450.0]

# %% [markdown]
# Question 14 prices = [100, 250, 500, 1000, 2500] Using map(), calculate the final price after adding 18% GST.

# %%
prices = [100, 250, 500, 1000, 2500]
final_price = list(map(lambda x:x+x*0.18,prices))
print(final_price)
# Out:
# [118.0, 295.0, 590.0, 1180.0, 2950.0]

# %% [markdown]
# Question 15 decimal_numbers = [12.4567, 45.8976, 78.1234, 99.9999] Using map(), round every number to two decimal places.

# %%
decimal_numbers = [12.4567, 45.8976, 78.1234, 99.9999]
round_number = list(map(lambda x:round(x,2),decimal_numbers))
print(round_number)
# Out:
# [12.46, 45.9, 78.12, 100.0]

# %% [markdown]
# Question 16 values = [-10, 20, -35, 40, -55, 60] Using map(), convert every number into its absolute value.

# %%
values = [-10, 20, -35, 40, -55, 60]
absolute = list(map(lambda x:abs(x),values))
print(absolute)
# Out:
# [10, 20, 35, 40, 55, 60]

# %% [markdown]
# Question 17 numbers = [10, 20, 30, 40, 50] Using map(), convert every integer into a string.

# %%
numbers = [10, 20, 30, 40, 50]
string = list(map(lambda x:str(x),numbers))
print(string)
# Out:
# ['10', '20', '30', '40', '50']

# %% [markdown]
# Question 18 names = [" Ravi ", " Anil", "Meena ", " Kiran "] Using map(), remove leading and trailing spaces from every name.

# %%
names = [" Ravi ", " Anil", "Meena ", " Kiran "]
remove = list(map(lambda x:x.strip(),names))
print(remove)
# Out:
# ['Ravi', 'Anil', 'Meena', 'Kiran']

# %% [markdown]
# Question 19 employees = [ {"id": 101, "name": "Rahul", "salary": 45000}, {"id": 102, "name": "Anil", "salary": 65000}, {"id": 103, "name": "Sneha", "salary": 72000}, {"id": 104, "name": "Kiran", "salary": 82000} ] Using map(), extract only employee names.

# %%
employees = [ {"id": 101, "name": "Rahul", "salary": 45000}, {"id": 102, "name": "Anil", "salary": 65000}, {"id": 103, "name": "Sneha", "salary": 72000}, {"id": 104, "name": "Kiran", "salary": 82000} ]
extract = list(map(lambda x:x["name"],employees))
print(extract)
# Out:
# ['Rahul', 'Anil', 'Sneha', 'Kiran']

# %% [markdown]
# Question 20 employees = [ {"id": 101, "name": "Rahul", "salary": 45000}, {"id": 102, "name": "Anil", "salary": 65000}, {"id": 103, "name": "Sneha", "salary": 72000}, {"id": 104, "name": "Kiran", "salary": 82000} ] Using map(), create a new list of dictionaries containing:
#
# Employee name Original salary Salary after a 10% increment Do not modify the original list.

# %%
employees = [ {"id": 101, "name": "Rahul", "salary": 45000}, {"id": 102, "name": "Anil", "salary": 65000}, {"id": 103, "name": "Sneha", "salary": 72000}, {"id": 104, "name": "Kiran", "salary": 82000} ]
new_list = list(map(lambda x:{"id":x["id"],"name":x["name"],"original_salary":x["salary"],"salary_after_increment":x["salary"]*1.10},employees))
print(new_list)
# Out:
# [{'id': 101, 'name': 'Rahul', 'original_salary': 45000, 'salary_after_increment': 49500.00000000001}, {'id': 102, 'name': 'Anil', 'original_salary': 65000, 'salary_after_increment': 71500.0}, {'id': 103, 'name': 'Sneha', 'original_salary': 72000, 'salary_after_increment': 79200.0}, {'id': 104, 'name': 'Kiran', 'original_salary': 82000, 'salary_after_increment': 90200.00000000001}]

# %% [markdown]
# Section 3: filter() — 20 Questions

# %% [markdown]
# Question 1
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# Using filter(), extract all even numbers.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
even = list(filter(lambda x:x%2==0,numbers))
print(even)
# Out:
# [12, 56, 34, 78, 100]

# %% [markdown]
# Question 2
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# Using filter(), extract all odd numbers.

# %%
numbers =[12,45,67,89,23,56,91,34,78,100]
odd = list(filter(lambda x:x%2 !=0,numbers))
print(odd)
# Out:
# [45, 67, 89, 23, 91]

# %% [markdown]
# Question 3
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# Using filter(), extract all numbers greater than 50.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
greater = list(filter(lambda x:x>50,numbers))
print(greater)
# Out:
# [67, 89, 56, 91, 78, 100]

# %% [markdown]
# Question 4
# numbers = [120, 45, 167, 89, 230, 56, 91, 34, 178, 100]
# Using filter(), extract all numbers less than 100.

# %%
numbers = [120, 45, 167, 89, 230, 56, 91, 34, 178, 100]
less = list(filter(lambda x:x<100,numbers))
print(less)
# Out:
# [45, 89, 56, 91, 34]

# %% [markdown]
# Question 5
# numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
# Using filter(), extract all positive numbers.

# %%
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
positive = list(filter(lambda x:x>0,numbers))
print(positive)
# Out:
# [4, 12, 37, 42]

# %% [markdown]
# Question 6
# numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
# Using filter(), extract all negative numbers.

# %%
numbers = [-15, -8, 0, 4, 12, -25, 37, 42]
negative = list(filter(lambda x:x<0,numbers))
print(negative)
# Out:
# [-15, -8, -25]

# %% [markdown]
# Question 7
# numbers = [-15, -8, 0, 4, 12, 0, -25, 37, 0]
# Using filter(), remove all zero values.

# %%
numbers = [-15, -8, 0, 4, 12, 0, -25, 37, 0]
remove = list(filter(lambda x:x!=0,numbers))
print(remove)
# Out:
# [-15, -8, 4, 12, -25, 37]

# %% [markdown]
# Question 8
# words = ["python", "azure", "ai", "developer", "cloud", "analytics"]
# Using filter(), extract words containing more than five characters.

# %%
words = ["python", "azure", "ai", "developer", "cloud", "analytics"]
more = list(filter(lambda x:len(x)>5,words))
print(more)
# Out:
# ['python', 'developer', 'analytics']

# %% [markdown]
# Question 9
# names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
# Using filter(), extract names beginning with "A".

# %%
names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
begin = list(filter(lambda x:x.startswith('A'),names))
print(begin)
# Out:
# ['Anil', 'Ajay', 'Arjun', 'Akhil']

# %% [markdown]
# Question 10
# names = ["Kiran", "Mohan", "Arjun", "Rajan", "Meena", "Varun"]
# Using filter(), extract names ending with "n".

# %%
names =  ["Kiran", "Mohan", "Arjun", "Rajan", "Meena", "Varun"]
end = list(filter(lambda x:x.endswith('n'),names))
print(end)
# Out:
# ['Kiran', 'Mohan', 'Arjun', 'Rajan', 'Varun']

# %% [markdown]
# Question 11
# numbers = [10, 15, 18, 20, 25, 30, 32, 40, 45, 50]
# Using filter(), extract all multiples of 5.

# %%
numbers = [10, 15, 18, 20, 25, 30, 32, 40, 45, 50]
multiples = list(filter(lambda x:x%5==0,numbers))
print(multiples)
# Out:
# [10, 15, 20, 25, 30, 40, 45, 50]

# %% [markdown]
# Question 12
# numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
# Using filter(), extract numbers divisible by both 3 and 5.

# %%
numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
divisible = list(filter(lambda x:x%3==0 and x%5==0,numbers))
print(divisible)
# Out:
# [15, 30, 45, 60, 75]

# %% [markdown]
# Question 13
# words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
# Using filter(), extract all palindrome words.

# %%
words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
palindrome = list(filter(lambda x:x==x[::-1],words))
print(palindrome)
# Out:
# ['madam', 'level', 'radar', 'civic']

# %% [markdown]
# Question 14
# emails = [
#     "john@gmail.com",
#     "rahul@yahoo.com",
#     "admin@python.com",
#     "support@azure.org",
#     "sales@company.com"
# ]
# Using filter(), extract email addresses ending with ".com".

# %%
emails = [ "john@gmail.com", "rahul@yahoo.com", "admin@python.com", "support@azure.org", "sales@company.com" ]
mail = list(filter(lambda x:x.endswith('.com'),emails))
print(mail)
# Out:
# ['john@gmail.com', 'rahul@yahoo.com', 'admin@python.com', 'sales@company.com']

# %% [markdown]
# Question 15
# files = [
#     "sales.csv",
#     "employees.xlsx",
#     "products.csv",
#     "report.pdf",
#     "customers.csv",
#     "notes.txt"
# ]
# Using filter(), extract all CSV files.

# %%
files = [ "sales.csv", "employees.xlsx", "products.csv", "report.pdf", "customers.csv", "notes.txt" ]
csv = list(filter(lambda x:x.endswith('.csv'),files))
print(csv)
# Out:
# ['sales.csv', 'products.csv', 'customers.csv']

# %% [markdown]
# Question 16
# employees = [
#     {"name": "Rahul", "salary": 45000},
#     {"name": "Anil", "salary": 65000},
#     {"name": "Sneha", "salary": 72000},
#     {"name": "Kiran", "salary": 82000},
#     {"name": "Meena", "salary": 55000}
# ]
# Using filter(), extract employees whose salary is greater than 60000.

# %%
employees = [ {"name": "Rahul", "salary": 45000}, {"name": "Anil", "salary": 65000}, {"name": "Sneha", "salary": 72000}, {"name": "Kiran", "salary": 82000}, {"name": "Meena", "salary": 55000} ]
salary = list(filter(lambda x:x["salary"]>60000,employees))
print(salary)
# Out:
# [{'name': 'Anil', 'salary': 65000}, {'name': 'Sneha', 'salary': 72000}, {'name': 'Kiran', 'salary': 82000}]

# %% [markdown]
# Question 17
# students = [
#     {"name": "Ravi", "marks": 92},
#     {"name": "Kiran", "marks": 68},
#     {"name": "Meena", "marks": 85},
#     {"name": "Ajay", "marks": 48},
#     {"name": "Sneha", "marks": 79}
# ]
# Using filter(), extract students who scored more than 80.

# %%
students = [ {"name": "Ravi", "marks": 92}, {"name": "Kiran", "marks": 68}, {"name": "Meena", "marks": 85}, {"name": "Ajay", "marks": 48}, {"name": "Sneha", "marks": 79} ]
marks = list(filter(lambda x:x["marks"]>80,students))
print(marks)
# Out:
# [{'name': 'Ravi', 'marks': 92}, {'name': 'Meena', 'marks': 85}]

# %% [markdown]
# Question 18
# products = [
#     {"name": "Laptop", "price": 55000, "stock": 5},
#     {"name": "Mouse", "price": 600, "stock": 25},
#     {"name": "Keyboard", "price": 1500, "stock": 0},
#     {"name": "Monitor", "price": 18000, "stock": 8},
#     {"name": "Printer", "price": 12000, "stock": 0}
# ]
# Using filter(), extract products that are currently in stock.

# %%
products = [ {"name": "Laptop", "price": 55000, "stock": 5}, {"name": "Mouse", "price": 600, "stock": 25}, {"name": "Keyboard", "price": 1500, "stock": 0}, {"name": "Monitor", "price": 18000, "stock": 8}, {"name": "Printer", "price": 12000, "stock": 0} ]
stock = list(filter(lambda x:x["stock"]>0,products))
print(stock)
# Out:
# [{'name': 'Laptop', 'price': 55000, 'stock': 5}, {'name': 'Mouse', 'price': 600, 'stock': 25}, {'name': 'Monitor', 'price': 18000, 'stock': 8}]

# %% [markdown]
# Question 19
# people = [
#     {"name": "Rahul", "age": 17},
#     {"name": "Anil", "age": 25},
#     {"name": "Sneha", "age": 16},
#     {"name": "Kiran", "age": 32},
#     {"name": "Meena", "age": 18}
# ]
# Using filter(), extract people who are eligible to vote.

# %%
people = [ {"name": "Rahul", "age": 17}, {"name": "Anil", "age": 25}, {"name": "Sneha", "age": 16}, {"name": "Kiran", "age": 32}, {"name": "Meena", "age": 18} ]
eligible = list(filter(lambda x:x["age"]>=18,people))
print(eligible)
# Out:
# [{'name': 'Anil', 'age': 25}, {'name': 'Kiran', 'age': 32}, {'name': 'Meena', 'age': 18}]

# %% [markdown]
# Question 20
# employees = [
#     {"name": "Rahul", "department": "IT", "active": True},
#     {"name": "Anil", "department": "HR", "active": True},
#     {"name": "Sneha", "department": "IT", "active": False},
#     {"name": "Kiran", "department": "IT", "active": True},
#     {"name": "Meena", "department": "Sales", "active": True}
# ]
# Using filter(), extract employees who belong to the IT department and are active.

# %%
employees = [ {"name": "Rahul", "department": "IT", "active": True}, {"name": "Anil", "department": "HR", "active": True}, {"name": "Sneha", "department": "IT", "active": False}, {"name": "Kiran", "department": "IT", "active": True}, {"name": "Meena", "department": "Sales", "active": True} ]
active = list(filter(lambda x:x["department"]=="IT" and x["active"]==True,employees))
print(active)
# Out:
# [{'name': 'Rahul', 'department': 'IT', 'active': True}, {'name': 'Kiran', 'department': 'IT', 'active': True}]

# %% [markdown]
# Section 4: reduce() — 20 Questions

# %% [markdown]
# Question 1
# numbers = [10, 20, 30, 40, 50]
# Using reduce(), calculate the sum of all numbers.

# %%
from functools import reduce
numbers = [10, 20, 30, 40, 50]
sum = reduce(lambda x,y:x+y,numbers)
print(sum)
# Out:
# 150

# %% [markdown]
# Question 2
# numbers = [2, 3, 4, 5]
# Using reduce(), calculate the product of all numbers.

# %%
numbers = [2, 3, 4, 5]
product = reduce(lambda x,y:x*y,numbers)
print(product)
# Out:
# 120

# %% [markdown]
# Question 3
# numbers = [45, 12, 89, 34, 67, 91, 28]
# Using reduce(), find the maximum number.

# %%
numbers = [45, 12, 89, 34, 67, 91, 28]
max = reduce(lambda x,y:x if x>y else y,numbers)
print(max)
# Out:
# 91

# %% [markdown]
# Question 4
# numbers = [45, 12, 89, 34, 67, 91, 28]
# Using reduce(), find the minimum number.

# %%
numbers = [45, 12, 89, 34, 67, 91, 28]
min = reduce(lambda x,y:x if x<y else y,numbers)
print(min)
# Out:
# 12

# %% [markdown]
# Question 5
# words = ["Python", " ", "is", " ", "powerful"]
# Using reduce(), combine all strings into one sentence.

# %%
words = ["Python", " ", "is", " ", "powerful"]
sentence = reduce(lambda x,y:x+y,words)
print(sentence)
# Out:
# Python is powerful

# %% [markdown]
# Question 6
# words = ["Python", "Azure", "Cloud", "AI"]
# Using reduce(), calculate the total number of characters in all words.

# %%
words = ["Python", "Azure", "Cloud", "AI"]
len_words = reduce(lambda x,y:x+len(y),words,0)
print(len_words)
# Out:
# 18

# %% [markdown]
# Question 7
# number = 6
# numbers = list(range(1, number + 1))
# Using reduce(), calculate the factorial of number.

# %%
number = 6
numbers = list(range(1, number + 1))
factorial = reduce(lambda x,y:x*y,numbers)
print(factorial)
# Out:
# 720

# %% [markdown]
# Question 8
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# Using reduce(), calculate the sum of only the even numbers. Do not create a separate filtered list.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
even = list(filter(lambda x:x%2==0,numbers))
sum = reduce(lambda x,y:x+y,even)
print(sum)
# Out:
# 280

# %% [markdown]
# Question 9
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# Using reduce(), calculate the sum of only the odd numbers. Do not create a separate filtered list.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
odd = list(filter(lambda x:x%2 !=0,numbers))
sum = reduce(lambda x,y:x+y,odd)
print(sum)
# Out:
# 315

# %% [markdown]
# Question 10
# words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
# Using reduce(), find the longest word.

# %%
words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
longest = reduce(lambda x,y:x if len(x)>len(y) else y,words)
print(longest)
# Out:
# Kubernetes

# %% [markdown]
# Question 11
# words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
# Using reduce(), find the shortest word.

# %%
 words = ["AI", "Python", "Databricks", "Cloud", "Kubernetes"]
 shortest = reduce(lambda x,y:x if len(x)<len(y) else y,words)
 print(shortest)
# Out:
# AI

# %% [markdown]
# Question 12
# salaries = [45000, 65000, 72000, 82000, 55000]
# Using reduce(), calculate the total salary.

# %%
salaries = [45000, 65000, 72000, 82000, 55000]
salary = reduce(lambda x,y:x+y,salaries)
print(salary)
# Out:
# 319000

# %% [markdown]
# Question 13
# employees = [
#     {"name": "Rahul", "salary": 45000},
#     {"name": "Anil", "salary": 65000},
#     {"name": "Sneha", "salary": 72000},
#     {"name": "Kiran", "salary": 82000},
#     {"name": "Meena", "salary": 55000}
# ]
# Using reduce(), calculate the total payroll directly from the dictionaries.

# %%
employees = [ {"name": "Rahul", "salary": 45000}, {"name": "Anil", "salary": 65000}, {"name": "Sneha", "salary": 72000}, {"name": "Kiran", "salary": 82000}, {"name": "Meena", "salary": 55000} ]
payroll = reduce(lambda x,y:x+y["salary"],employees,0)
print(payroll)
# Out:
# 319000

# %% [markdown]
# Question 14
# employees = [
#     {"name": "Rahul", "salary": 45000},
#     {"name": "Anil", "salary": 65000},
#     {"name": "Sneha", "salary": 72000},
#     {"name": "Kiran", "salary": 82000},
#     {"name": "Meena", "salary": 55000}
# ]
# Using reduce(), find the employee with the highest salary.

# %%
employees = [ {"name": "Rahul", "salary": 45000}, {"name": "Anil", "salary": 65000}, {"name": "Sneha", "salary": 72000}, {"name": "Kiran", "salary": 82000}, {"name": "Meena", "salary": 55000} ]
highest = reduce(lambda x,y:x if x["salary"]>y["salary"] else y,employees)
print(highest)
# Out:
# {'name': 'Kiran', 'salary': 82000}

# %% [markdown]
# Question 15
# students = [
#     {"name": "Ravi", "marks": 92},
#     {"name": "Kiran", "marks": 68},
#     {"name": "Meena", "marks": 85},
#     {"name": "Ajay", "marks": 48},
#     {"name": "Rahul", "marks": 95}
# ]
# Using reduce(), find the student with the highest marks.

# %%
students = [ {"name": "Ravi", "marks": 92}, {"name": "Kiran", "marks": 68}, {"name": "Meena", "marks": 85}, {"name": "Ajay", "marks": 48}, {"name": "Rahul", "marks": 95} ]
highest = reduce(lambda x,y:x if x["marks"]>y["marks"] else y,students)
print(highest)
# Out:
# {'name': 'Rahul', 'marks': 95}

# %% [markdown]
# Question 16
# products = [
#     {"name": "Laptop", "price": 55000, "stock": 5},
#     {"name": "Mouse", "price": 600, "stock": 25},
#     {"name": "Keyboard", "price": 1500, "stock": 15},
#     {"name": "Monitor", "price": 18000, "stock": 8}
# ]
# Using reduce(), calculate the total stock quantity.

# %%
products = [ {"name": "Laptop", "price": 55000, "stock": 5}, {"name": "Mouse", "price": 600, "stock": 25}, {"name": "Keyboard", "price": 1500, "stock": 15}, {"name": "Monitor", "price": 18000, "stock": 8} ]
stock = reduce(lambda x,y:x+y["stock"],products,0)
print(stock)
# Out:
# 53

# %% [markdown]
# Question 17
# products = [
#     {"name": "Laptop", "price": 55000, "stock": 5},
#     {"name": "Mouse", "price": 600, "stock": 25},
#     {"name": "Keyboard", "price": 1500, "stock": 15},
#     {"name": "Monitor", "price": 18000, "stock": 8}
# ]
# Using reduce(), calculate the total inventory value using price × stock.

# %%
products = [ {"name": "Laptop", "price": 55000, "stock": 5}, {"name": "Mouse", "price": 600, "stock": 25}, {"name": "Keyboard", "price": 1500, "stock": 15}, {"name": "Monitor", "price": 18000, "stock": 8} ]
inventory = reduce(lambda x,y:x+y["price"]*y["stock"],products,0)
print(inventory)
# Out:
# 456500

# %% [markdown]
# Question 18
# sales = [12000, 25000, 18000, 45000, 30000, 52000]
# Using reduce(), calculate the total sales amount.

# %%
sales = [12000, 25000, 18000, 45000, 30000, 52000]
sum = reduce(lambda x,y:x+y,sales)
print(sum)
# Out:
# 182000

# %% [markdown]
# Question 19
# dictionaries = [
#     {"name": "Rahul"},
#     {"age": 30},
#     {"department": "IT"},
#     {"salary": 65000}
# ]
# Using reduce(), merge all dictionaries into one dictionary.

# %%
dictionaries = [ {"name": "Rahul"}, {"age": 30}, {"department": "IT"}, {"salary": 65000} ]
merge = reduce(lambda x,y:x|y,dictionaries)
print(merge)
# Out:
# {'name': 'Rahul', 'age': 30, 'department': 'IT', 'salary': 65000}

# %% [markdown]
# Question 20
# numbers = [12, 45, 12, 67, 45, 89, 23, 67, 100]
# Using reduce(), calculate the sum of unique numbers only. Do not directly use sum(set(numbers)).

# %%
numbers = [12, 45, 12, 67, 45, 89, 23, 67, 100]
unique = list(set(numbers))
sum = reduce(lambda x,y:x+y,unique)
print(sum)
# Out:
# 336

# %% [markdown]
# Section 5: Combined Lambda, map(), filter(), and reduce() — 20 Questions

# %% [markdown]
# Question 1
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# Using filter() and map():
#
# Extract all even numbers.
# Calculate the square of every even number.
# Return the squared values as a list.

# %%
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
even = list(filter(lambda x:x%2==0,numbers))
square = list(map(lambda x:x**2,even))
print(even)
print(square)
# Out:
# [12, 56, 34, 78, 100]
# [144, 3136, 1156, 6084, 10000]

# %% [markdown]
# Question 2
# numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
# Using filter() and reduce():
#
# Extract all odd numbers.
# Calculate their total sum.

# %%
from functools import reduce
numbers = [12, 45, 67, 89, 23, 56, 91, 34, 78, 100]
odd = list(filter(lambda x:x%2 !=0,numbers))
total_sum = reduce(lambda x,y:x+y,odd)
print(odd)
print(total_sum)
# Out:
# [45, 67, 89, 23, 91]
# 315

# %% [markdown]
# Question 3
# numbers = [10, 25, 40, 55, 70, 85, 100]
# Using filter() and map():
#
# Extract numbers greater than 50.
# Multiply every selected number by 2.

# %%
numbers = [10, 25, 40, 55, 70, 85, 100]
even = list(filter(lambda x:x>50,numbers))
multiply = list(map(lambda x:x*2,even))
print(even)
print(multiply)
# Out:
# [55, 70, 85, 100]
# [110, 140, 170, 200]

# %% [markdown]
# Question 4
# numbers = [-15, 20, -35, 40, 50, -10, 60]
# Using filter(), map(), and reduce():
#
# Extract positive numbers.
# Calculate the square of every positive number.
# Calculate the total sum of the squared values.

# %%
numbers = [-15, 20, -35, 40, 50, -10, 60]
positive = list(filter(lambda x:x>0,numbers))
square = list(map(lambda x:x**2,positive))
total_sum = reduce(lambda x,y:x+y,square)
print(positive)
print(square)
print(total_sum)
# Out:
# [20, 40, 50, 60]
# [400, 1600, 2500, 3600]
# 8100

# %% [markdown]
# Question 5
# words = ["python", "azure", "ai", "developer", "cloud", "analytics", "spark"]
# Using filter() and map():
#
# Extract words containing more than five characters.
# Convert the selected words to uppercase.

# %%
words = ["python", "azure", "ai", "developer", "cloud", "analytics", "spark"]
length = list(filter(lambda x:len(x)>5,words))
upper = list(map(lambda x:x.upper(),length))
print(length)
print(upper)
# Out:
# ['python', 'developer', 'analytics']
# ['PYTHON', 'DEVELOPER', 'ANALYTICS']

# %% [markdown]
# Question 6
# names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
# Using filter() and map():
#
# Extract names beginning with "A".
# Convert the selected names to lowercase.

# %%
names = ["Anil", "Rahul", "Ajay", "Meena", "Arjun", "Kiran", "Akhil"]
length = list(filter(lambda x:x[0]=="A",names))
lower = list(map(lambda x:x.lower(),length))
print(length)
print(lower)
# Out:
# ['Anil', 'Ajay', 'Arjun', 'Akhil']
# ['anil', 'ajay', 'arjun', 'akhil']

# %% [markdown]
# Question 7
# numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
# Using filter() and reduce():
#
# Extract numbers divisible by both 3 and 5.
# Calculate their total sum.

# %%
numbers = [3, 5, 10, 15, 18, 30, 42, 45, 60, 75]
divisible = list(filter(lambda x:x%3==0 and x%5==0,numbers))
total_sum = reduce(lambda x,y:x+y,divisible)
print(divisible)
print(total_sum)
# Out:
# [15, 30, 45, 60, 75]
# 225

# %% [markdown]
# Question 8
# words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
# Using filter() and reduce():
#
# Extract palindrome words.
# Join them into one string separated by " | ".

# %%
words = ["madam", "python", "level", "azure", "radar", "cloud", "civic"]
palindrome = list(filter(lambda x:x==x[::-1],words))
join = reduce(lambda x,y:x+" | "+y,palindrome)
print(palindrome)
print(join)
# Out:
# ['madam', 'level', 'radar', 'civic']
# madam | level | radar | civic

# %% [markdown]
# Question 9
# temperatures = [18, 24, 30, 35, 40, 12, 28, 33, 15, 42]
# Using filter(), map(), and reduce():
#
# Extract temperatures greater than 30°C.
# Convert the selected values into Fahrenheit.
# Calculate the average Fahrenheit temperature.

# %%
temperatures = [18, 24, 30, 35, 40, 12, 28, 33, 15, 42]
celsius = list(filter(lambda x:x>30,temperatures))
fahrenheit = list(map(lambda x:(x*9/5)+32,celsius))
avg = reduce(lambda x,y:x+y,fahrenheit)/len(fahrenheit)
print(celsius)
print(fahrenheit)
print(avg)
# Out:
# [35, 40, 33, 42]
# [95.0, 104.0, 91.4, 107.6]
# 99.5

# %% [markdown]
# Question 10
# prices = [450, 1200, 2500, 800, 5000, 1500, 7500]
# Using filter(), map(), and reduce():
#
# Extract prices greater than 1000.
# Apply a 10% discount to every selected price.
# Calculate the total discounted amount.

# %%
prices = [450, 1200, 2500, 800, 5000, 1500, 7500]
discount = list(filter(lambda x:x>1000,prices))
discounted = list(map(lambda x:x*0.9,discount))
total = reduce(lambda x,y:x+y,discounted)
print(discount)
print(discounted)
print(total)
# Out:
# [1200, 2500, 5000, 1500, 7500]
# [1080.0, 2250.0, 4500.0, 1350.0, 6750.0]
# 15930.0

# %% [markdown]
# Question 11
# employees = [
#     {"id": 101, "name": "Rahul", "salary": 45000},
#     {"id": 102, "name": "Anil", "salary": 65000},
#     {"id": 103, "name": "Sneha", "salary": 72000},
#     {"id": 104, "name": "Kiran", "salary": 82000},
#     {"id": 105, "name": "Meena", "salary": 55000}
# ]
# Using filter() and map():
#
# Extract employees earning more than 60000.
# Increase their salary by 10%.
# Return their names and updated salaries.

# %%
employees = [ {"id": 101, "name": "Rahul", "salary": 45000}, {"id": 102, "name": "Anil", "salary": 65000}, {"id": 103, "name": "Sneha", "salary": 72000}, {"id": 104, "name": "Kiran", "salary": 82000}, {"id": 105, "name": "Meena", "salary": 55000} ]
extracts = list(filter(lambda x:x["salary"]>60000,employees))
increase = list(map(lambda x:{"name":x["name"],"salary":x["salary"]*1.1},extracts))
print(extracts)
print(increase)
# Out:
# [{'id': 102, 'name': 'Anil', 'salary': 65000}, {'id': 103, 'name': 'Sneha', 'salary': 72000}, {'id': 104, 'name': 'Kiran', 'salary': 82000}]
# [{'name': 'Anil', 'salary': 71500.0}, {'name': 'Sneha', 'salary': 79200.0}, {'name': 'Kiran', 'salary': 90200.00000000001}]

# %% [markdown]
# Question 12
# employees = [
#     {"id": 101, "name": "Rahul", "department": "IT", "salary": 45000},
#     {"id": 102, "name": "Anil", "department": "HR", "salary": 65000},
#     {"id": 103, "name": "Sneha", "department": "IT", "salary": 72000},
#     {"id": 104, "name": "Kiran", "department": "IT", "salary": 82000},
#     {"id": 105, "name": "Meena", "department": "Sales", "salary": 55000}
# ]
# Using filter() and reduce():
#
# Extract employees from the IT department.
# Calculate the total salary of IT employees.

# %%
employees = [ {"id": 101, "name": "Rahul", "department": "IT", "salary": 45000}, {"id": 102, "name": "Anil", "department": "HR", "salary": 65000}, {"id": 103, "name": "Sneha", "department": "IT", "salary": 72000}, {"id": 104, "name": "Kiran", "department": "IT", "salary": 82000}, {"id": 105, "name": "Meena", "department": "Sales", "salary": 55000} ]
it = list(filter(lambda x:x["department"]=="IT",employees))
salary = reduce(lambda x,y:x+y["salary"],it,0)
print(it)
print(salary)
# Out:
# [{'id': 101, 'name': 'Rahul', 'department': 'IT', 'salary': 45000}, {'id': 103, 'name': 'Sneha', 'department': 'IT', 'salary': 72000}, {'id': 104, 'name': 'Kiran', 'department': 'IT', 'salary': 82000}]
# 199000

# %% [markdown]
# Question 13
# employees = [
#     {"id": 101, "name": "Rahul", "salary": 45000, "active": True},
#     {"id": 102, "name": "Anil", "salary": 65000, "active": True},
#     {"id": 103, "name": "Sneha", "salary": 72000, "active": False},
#     {"id": 104, "name": "Kiran", "salary": 82000, "active": True},
#     {"id": 105, "name": "Meena", "salary": 55000, "active": True},
#     {"id": 106, "name": "Arjun", "salary": 98000, "active": False}
# ]
# Using filter(), map(), and reduce():
#
# Extract active employees.
# Increase every active employee's salary by 15%.
# Calculate the total updated payroll.

# %%
employees = [ {"id": 101, "name": "Rahul", "salary": 45000, "active": True}, {"id": 102, "name": "Anil", "salary": 65000, "active": True}, {"id": 103, "name": "Sneha", "salary": 72000, "active": False}, {"id": 104, "name": "Kiran", "salary": 82000, "active": True}, {"id": 105, "name": "Meena", "salary": 55000, "active": True}, {"id": 106, "name": "Arjun", "salary": 98000, "active": False} ]
active = list(filter(lambda x:x["active"]==True,employees))
increase = list(map(lambda x:{"name":x["name"],"salary":x["salary"]*1.15},active))
payroll = reduce(lambda x,y:x+y["salary"],increase,0)
print(active)
print(increase)
print(payroll)
# Out:
# [{'id': 101, 'name': 'Rahul', 'salary': 45000, 'active': True}, {'id': 102, 'name': 'Anil', 'salary': 65000, 'active': True}, {'id': 104, 'name': 'Kiran', 'salary': 82000, 'active': True}, {'id': 105, 'name': 'Meena', 'salary': 55000, 'active': True}]
# [{'name': 'Rahul', 'salary': 51749.99999999999}, {'name': 'Anil', 'salary': 74750.0}, {'name': 'Kiran', 'salary': 94299.99999999999}, {'name': 'Meena', 'salary': 63249.99999999999}]
# 284050.0

# %% [markdown]
# Question 14
# students = [
#     {"name": "Ravi", "marks": 92, "passed": True},
#     {"name": "Kiran", "marks": 68, "passed": True},
#     {"name": "Meena", "marks": 85, "passed": True},
#     {"name": "Ajay", "marks": 48, "passed": True},
#     {"name": "Sneha", "marks": 35, "passed": False},
#     {"name": "Rahul", "marks": 95, "passed": True}
# ]
# Using filter() and reduce():
#
# Extract students who passed.
# Find the topper among the passed students.

# %%
students = [ {"name": "Ravi", "marks": 92, "passed": True}, {"name": "Kiran", "marks": 68, "passed": True}, {"name": "Meena", "marks": 85, "passed": True}, {"name": "Ajay", "marks": 48, "passed": True}, {"name": "Sneha", "marks": 35, "passed": False}, {"name": "Rahul", "marks": 95, "passed": True} ]
passed = list(filter(lambda x:x["passed"]==True,students))
topper = reduce(lambda x,y:x if x["marks"]>y["marks"] else y,passed)
print(passed)
print(topper)
# Out:
# [{'name': 'Ravi', 'marks': 92, 'passed': True}, {'name': 'Kiran', 'marks': 68, 'passed': True}, {'name': 'Meena', 'marks': 85, 'passed': True}, {'name': 'Ajay', 'marks': 48, 'passed': True}, {'name': 'Rahul', 'marks': 95, 'passed': True}]
# {'name': 'Rahul', 'marks': 95, 'passed': True}

# %% [markdown]
# Question 15
# students = [
#     {"name": "Ravi", "marks": 92},
#     {"name": "Kiran", "marks": 68},
#     {"name": "Meena", "marks": 85},
#     {"name": "Ajay", "marks": 48},
#     {"name": "Sneha", "marks": 79},
#     {"name": "Rahul", "marks": 95}
# ]
# Using filter(), map(), and reduce():
#
# Extract students scoring more than 70.
# Extract only their marks.
# Calculate the average marks.

# %%
students = [ {"name": "Ravi", "marks": 92}, {"name": "Kiran", "marks": 68}, {"name": "Meena", "marks": 85}, {"name": "Ajay", "marks": 48}, {"name": "Sneha", "marks": 79}, {"name": "Rahul", "marks": 95} ]
extracts = list(filter(lambda x:x["marks"]>70,students))
marks = list(map(lambda x:x["marks"],extracts))
avg = reduce(lambda x,y:x+y,marks)/len(marks)
print(extracts)
print(marks)
print(avg)
# Out:
# [{'name': 'Ravi', 'marks': 92}, {'name': 'Meena', 'marks': 85}, {'name': 'Sneha', 'marks': 79}, {'name': 'Rahul', 'marks': 95}]
# [92, 85, 79, 95]
# 87.75

# %% [markdown]
# Question 16
# products = [
#     {"name": "Laptop", "price": 55000, "stock": 5},
#     {"name": "Mouse", "price": 600, "stock": 25},
#     {"name": "Keyboard", "price": 1500, "stock": 0},
#     {"name": "Monitor", "price": 18000, "stock": 8},
#     {"name": "Printer", "price": 12000, "stock": 0},
#     {"name": "SSD", "price": 6500, "stock": 12}
# ]
# Using filter(), map(), and reduce():
#
# Extract products currently in stock.
# Calculate each product's inventory value using price × stock.
# Calculate the total inventory value.

# %%
products = [ {"name": "Laptop", "price": 55000, "stock": 5}, {"name": "Mouse", "price": 600, "stock": 25}, {"name": "Keyboard", "price": 1500, "stock": 0}, {"name": "Monitor", "price": 18000, "stock": 8}, {"name": "Printer", "price": 12000, "stock": 0}, {"name": "SSD", "price": 6500, "stock": 12} ]
stock = list(filter(lambda x:x["stock"]>0,products))
inventory = list(map(lambda x:x["price"]*x["stock"],stock))
total = reduce(lambda x,y:x+y,inventory)
print(stock)
print(inventory)
print(total)
# Out:
# [{'name': 'Laptop', 'price': 55000, 'stock': 5}, {'name': 'Mouse', 'price': 600, 'stock': 25}, {'name': 'Monitor', 'price': 18000, 'stock': 8}, {'name': 'SSD', 'price': 6500, 'stock': 12}]
# [275000, 15000, 144000, 78000]
# 512000

# %% [markdown]
# Question 17
# products = [
#     {"name": "Laptop", "price": 55000, "category": "Electronics"},
#     {"name": "Chair", "price": 4500, "category": "Furniture"},
#     {"name": "Monitor", "price": 18000, "category": "Electronics"},
#     {"name": "Desk", "price": 8500, "category": "Furniture"},
#     {"name": "SSD", "price": 6500, "category": "Electronics"}
# ]
# Using filter(), map(), and reduce():
#
# Extract products belonging to the Electronics category.
# Apply a 20% discount.
# Calculate the total discounted value.

# %%
products = [ {"name": "Laptop", "price": 55000, "category": "Electronics"}, {"name": "Chair", "price": 4500, "category": "Furniture"}, {"name": "Monitor", "price": 18000, "category": "Electronics"}, {"name": "Desk", "price": 8500, "category": "Furniture"}, {"name": "SSD", "price": 6500, "category": "Electronics"} ]
electronics = list(filter(lambda x:x["category"]=="Electronics",products))
discount = list(map(lambda x:{"name":x["name"],"price":x["price"]*0.8},electronics))
total = reduce(lambda x,y:x+y["price"],discount,0)
print(electronics)
print(discount)
print(total)
# Out:
# [{'name': 'Laptop', 'price': 55000, 'category': 'Electronics'}, {'name': 'Monitor', 'price': 18000, 'category': 'Electronics'}, {'name': 'SSD', 'price': 6500, 'category': 'Electronics'}]
# [{'name': 'Laptop', 'price': 44000.0}, {'name': 'Monitor', 'price': 14400.0}, {'name': 'SSD', 'price': 5200.0}]
# 63600.0

# %% [markdown]
# Question 18
# orders = [
#     {"order_id": 1001, "amount": 1200, "status": "Delivered"},
#     {"order_id": 1002, "amount": 3500, "status": "Pending"},
#     {"order_id": 1003, "amount": 8500, "status": "Delivered"},
#     {"order_id": 1004, "amount": 4200, "status": "Cancelled"},
#     {"order_id": 1005, "amount": 7600, "status": "Delivered"},
#     {"order_id": 1006, "amount": 5100, "status": "Pending"}
# ]
# Using filter() and reduce():
#
# Extract delivered orders.
# Calculate the total delivered revenue.

# %%
orders = [ {"order_id": 1001, "amount": 1200, "status": "Delivered"}, {"order_id": 1002, "amount": 3500, "status": "Pending"}, {"order_id": 1003, "amount": 8500, "status": "Delivered"}, {"order_id": 1004, "amount": 4200, "status": "Cancelled"}, {"order_id": 1005, "amount": 7600, "status": "Delivered"}, {"order_id": 1006, "amount": 5100, "status": "Pending"} ]
delivered = list(filter(lambda x:x["status"]=="Delivered",orders))
revenue = reduce(lambda x,y:x+y["amount"],delivered,0)
print(delivered)
print(revenue)
# Out:
# [{'order_id': 1001, 'amount': 1200, 'status': 'Delivered'}, {'order_id': 1003, 'amount': 8500, 'status': 'Delivered'}, {'order_id': 1005, 'amount': 7600, 'status': 'Delivered'}]
# 17300

# %% [markdown]
# Question 19
# transactions = [
#     {"id": 1, "amount": 1200},
#     {"id": 2, "amount": 5200},
#     {"id": 3, "amount": 18000},
#     {"id": 4, "amount": 2500},
#     {"id": 5, "amount": 9600},
#     {"id": 6, "amount": 7200}
# ]
# Using filter(), map(), and reduce():
#
# Extract transactions whose amount is greater than 5000.
# Add 18% GST to every selected transaction.
# Calculate the grand total after GST.

# %%
from functools import reduce
transactions = [ {"id": 1, "amount": 1200}, {"id": 2, "amount": 5200}, {"id": 3, "amount": 18000}, {"id": 4, "amount": 2500}, {"id": 5, "amount": 9600}, {"id": 6, "amount": 7200} ]
extracts = list(filter(lambda x:x["amount"]>5000,transactions))
GST =list(map(lambda x:x["amount"]*1.18,extracts))
total = reduce(lambda x,y:x+y,GST,0)
print(extracts)
print(GST)
print(total)
# Out:
# [{'id': 2, 'amount': 5200}, {'id': 3, 'amount': 18000}, {'id': 5, 'amount': 9600}, {'id': 6, 'amount': 7200}]
# [6136.0, 21240.0, 11328.0, 8496.0]
# 47200.0

# %% [markdown]
# Question 20
# sales_records = [
#     {"salesperson": "Rahul", "region": "South", "sales": 45000, "active": True},
#     {"salesperson": "Anil", "region": "North", "sales": 65000, "active": True},
#     {"salesperson": "Sneha", "region": "South", "sales": 72000, "active": False},
#     {"salesperson": "Kiran", "region": "South", "sales": 82000, "active": True},
#     {"salesperson": "Meena", "region": "West", "sales": 55000, "active": True},
#     {"salesperson": "Arjun", "region": "South", "sales": 98000, "active": True}
# ]
# Using filter(), map(), and reduce():
#
# Extract active salespeople from the South region.
# Calculate a 5% incentive for each selected salesperson.
# Create a list containing salesperson name, sales amount, and incentive.
# Calculate the total incentive payable.

# %%
sales_records = [ {"salesperson": "Rahul", "region": "South", "sales": 45000, "active": True}, {"salesperson": "Anil", "region": "North", "sales": 65000, "active": True}, {"salesperson": "Sneha", "region": "South", "sales": 72000, "active": False}, {"salesperson": "Kiran", "region": "South", "sales": 82000, "active": True}, {"salesperson": "Meena", "region": "West", "sales": 55000, "active": True}, {"salesperson": "Arjun", "region": "South", "sales": 98000, "active": True} ]
active = list(filter(lambda x:x["active"]==True and x["region"]=="South",sales_records))
incremented = list(map(lambda x:{"salesperson":x["salesperson"],"sales":x["sales"],"incentive":x["sales"]*0.05},active))
total = reduce(lambda x,y:x+y["incentive"],incremented,0)
print(active)
print(incremented)
print(total)
# Out:
# [{'salesperson': 'Rahul', 'region': 'South', 'sales': 45000, 'active': True}, {'salesperson': 'Kiran', 'region': 'South', 'sales': 82000, 'active': True}, {'salesperson': 'Arjun', 'region': 'South', 'sales': 98000, 'active': True}]
# [{'salesperson': 'Rahul', 'sales': 45000, 'incentive': 2250.0}, {'salesperson': 'Kiran', 'sales': 82000, 'incentive': 4100.0}, {'salesperson': 'Arjun', 'sales': 98000, 'incentive': 4900.0}]
# 11250.0
