# %% [markdown]
# # Banking Assignment — Object-Oriented Programming (100 Questions with Hints)
#
# An unsolved assessment notebook using accounts, deposits, withdrawals, transfers, cards, loans, KYC, fraud monitoring, reconciliation, and audit trails.
#
# **Structure:** 30 easy + 40 medium + 30 difficult = **100 questions**.

# %% [markdown]
# ## Student instructions
#
# Solve all questions using banking scenarios. Practice classes, objects, instance/class attributes, methods, encapsulation, inheritance, polymorphism, composition, abstract classes, dataclasses, properties, protocols, and design patterns. Do not store real customer data, credentials, PINs, or complete card numbers. Each question includes a graduated hint but intentionally has no solution.
#
# **Recommended workflow:** write assumptions, implement the smallest correct function/class, test normal and edge cases, then explain your design.

# %% [markdown]
# ---
#
# ## Easy
#
# Fundamentals and direct applications.

# %% [markdown]
# ### Q1. Create a account class for banking case 1; use sample reference `ACC-1001` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
  def __init__(self, account_number, balance=0):
    self.account_number=account_number
    self.balance=balance
  def deposit(self,amount):
    if amount<=0:
      raise ValueError("Deposit amount must be greater than zero")
    self.balance=self.balance+amount
  def withdraw(self,amount):
    if amount<0:
      raise ValueError("withdraw amount must be greater than zero")
    if amount>self.balance:
      raise ValueError("insufficient balance")
    self.balance=self.balance-amount
  def transfer(self,other_account,amount):
    self.withdraw(amount)
    other_account.deposit(amount)
  def show_balance(self):
    print("Account:",self.account_number)
    print("Balance:",self.balance)
account1=Account("ACC-1001",5000)
account1.deposit(1000)
account1.withdraw(2000)
account1.show_balance()
# Out:
# Account: ACC-1001
# Balance: 4000

# %% [markdown]
# ### Q2. Add an initializer to accountholder for banking case 1; use sample reference `ACC-1002` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance=0):
        self.account_number=account_number
        self.__balance=balance

    def deposit(self, amount):
        if amount<=0:
            raise ValueError("Deposit amount must be greater than zero")
        self.__balance=self.__balance+amount

    def withdraw(self, amount):
        if amount<=0:
            raise ValueError("Withdrawal amount must be greater than zero")
        if amount>self.__balance:
            raise ValueError("Insufficient balance")
        self.__balance=self.__balance-amount

    def show_balance(self):
        print("Account:",self.account_number)
        print("Balance:",self.__balance)


class AccountHolder:
    def __init__(self, name, phone, account):
        self.name=name
        self.phone=phone
        self.account=account

    def show_details(self):
        print("Name:",self.name)
        print("Phone:",self.phone)
        self.account.show_balance()


account=Account("ACC-1002",5000)
holder=AccountHolder("Ravi","9876543210",account)

holder.show_details()
# Out:
# Name: Ravi
# Phone: 9876543210
# Account: ACC-1002
# Balance: 5000

# %% [markdown]
# ### Q3. Represent an transfer object for banking case 1; use sample reference `ACC-1003` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class transfer:
  def __init__(self,transfer_id,from_account,to_account,amount):
    self.transfer_id=transfer_id
    self.from_account=from_account
    self.to_account=to_account
    self.amount=amount
  def show_transfer(self):
    print("Transfer ID:",self.transfer_id)
    print("From Account:",self.from_account)
    print("To Account:",self.to_account)
    print("Amount:",self.amount)
transfer=transfer("ACC-1003","ACC-1001","ACC-1002",2000)
transfer.show_transfer()
# Out:
# Transfer ID: ACC-1003
# From Account: ACC-1001
# To Account: ACC-1002
# Amount: 2000

# %% [markdown]
# ### Q4. Add a method that calculates line total for banking case 1; use sample reference `ACC-1004` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class transfer:
  def __init__(self,transfer_id, quantity,unit_amount):
    self.transfer_id=transfer_id
    self.quantity=quantity
    self.unit_amount=unit_amount
  def line_total(self):
    if self.quantity<0:
      raise ValueError("quantity cannot be negative")
    if self.unit_amount<0:
      raise ValueError("unit amount cannot be negative")
    return self.quantity*self.unit_amount
transfer=transfer("ACC-1004",2,2000)
print("transaction ID:",transfer.transfer_id)
print("line total:",transfer.line_total())
# Out:
# transaction ID: ACC-1004
# line total: 4000

# %% [markdown]
# ### Q5. Use a class attribute for branch name for banking case 1; use sample reference `ACC-1005` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
  branch_name="main branch"
  def __init__(self,account_number,balance=0):
    self.account_number=account_number
    self.__balance=balance
  def show_details(self):
    print("Account:",self.account_number)
    print("Branch:",Account.branch_name)
    print("Balance:",self.__balance)
account1=Account("ACC-1005",5000)
account1.show_details()
# Out:
# Account: ACC-1005
# Branch: main branch
# Balance: 5000

# %% [markdown]
# ### Q6. Write a readable __str__ method for banking case 1; use sample reference `ACC-1006` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance):
        self.account_number=account_number
        self.balance=balance
    def __str__(self):
        return "Account: " + self.account_number + ", Balance: " + str(self.balance)
account=Account("ACC-1006",5000)
print(account)
# Out:
# Account: ACC-1006, Balance: 5000

# %% [markdown]
# ### Q7. Compare two account references with __eq__ for banking case 1; use sample reference `ACC-1007` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
  def __init__(self,account_number,balance):
    self.account_number=account_number
    self.balance=balance
  def __eq__(self, other):
    if not isinstance(other, Account):
      return False
    return self.account_number==other.account_number
account1=Account("ACC-1007",5000)
account2=Account("ACC-1007",5000)

# %% [markdown]
# ### Q8. Protect a amount with a property for banking case 1; use sample reference `ACC-1008` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
  def __init__(self,account_number,balance):
    self.account_number=account_number
    self.__balance=balance
  @property
  def balance(self):
    return self.__balance
  @balance.setter
  def balance(self,value):
    if not isinstance(value,(int,float)):
      raise TypeError("balance must be a number")
    if value<0:
      raise ValueError("balance cannot be negative")
    self.__balance=value

account=Account("ACC-1008",5000)
print("Account:",account.account_number)
print("Balance:",account.balance)
account.balance=7000
print("Updated balance:",account.balance)
# Out:
# Account: ACC-1008
# Balance: 5000
# Updated balance: 7000

# %% [markdown]
# ### Q9. Create portfolio and add_item for banking case 1; use sample reference `ACC-1009` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Portfolio:
    def __init__(self, portfolio_id):
        self.portfolio_id=portfolio_id
        self.items=[]

    def add_item(self, item):
        if item=="":
            raise ValueError("Item cannot be empty")
        self.items.append(item)

    def show_portfolio(self):
        print("Portfolio ID:",self.portfolio_id)
        print("Items:",self.items)


portfolio=Portfolio("ACC-1009")

portfolio.add_item("Savings Account")
portfolio.add_item("Fixed Deposit")

portfolio.show_portfolio()
# Out:
# Portfolio ID: ACC-1009
# Items: ['Savings Account', 'Fixed Deposit']

# %% [markdown]
# ### Q10. Model a branchaddress for banking case 1; use sample reference `ACC-1010` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BranchAddress:
    def __init__(self, branch_id, street, city, state, pincode):
        self.branch_id=branch_id
        self.street=street
        self.city=city
        self.state=state
        self.pincode=pincode

    def show_address(self):
        print("Branch ID:",self.branch_id)
        print("Address:",self.street)
        print("City:",self.city)
        print("State:",self.state)
        print("Pincode:",self.pincode)


branch=BranchAddress("ACC-1010","MG Road","Bengaluru","Karnataka","560001")

branch.show_address()
# Out:
# Branch ID: ACC-1010
# Address: MG Road
# City: Bengaluru
# State: Karnataka
# Pincode: 560001

# %% [markdown]
# ### Q11. Use a static method to validate account reference for banking case 1; use sample reference `ACC-1011` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance=0):
        self.account_number=account_number
        self.__balance=balance

    @staticmethod
    def validate_account_reference(account_number):
        if not isinstance(account_number,str):
            return False
        if account_number=="":
            return False
        if not account_number.startswith("ACC-"):
            return False
        if not account_number[4:].isdigit():
            return False
        return True

    def show_balance(self):
        print("Account:",self.account_number)
        print("Balance:",self.__balance)

account_number="ACC-1011"

if Account.validate_account_reference(account_number):
    account=Account(account_number,5000)
    account.show_balance()
else:
    print("Invalid account reference")
# Out:
# Account: ACC-1011
# Balance: 5000

# %% [markdown]
# ### Q12. Use a class method as an alternate constructor for banking case 1; use sample reference `ACC-1012` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance=0):
        self.account_number=account_number
        self.__balance=balance

    @classmethod
    def create_account(cls, account_number):
        return cls(account_number, 0)

    def show_balance(self):
        print("Account:",self.account_number)
        print("Balance:",self.__balance)

account=Account.create_account("ACC-1012")
account.show_balance()

# %% [markdown]
# ### Q13. Track object count for banking case 1; use sample reference `ACC-1013` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    account_count=0

    def __init__(self, account_number, balance=0):
        self.account_number=account_number
        self.__balance=balance
        Account.account_count+=1

    @classmethod
    def show_account_count(cls):
        print("Total accounts:",cls.account_count)

    def show_balance(self):
        print("Account:",self.account_number)
        print("Balance:",self.__balance)

account1=Account("ACC-1013",5000)
account2=Account("ACC-1014",3000)

account1.show_balance()
account2.show_balance()
Account.show_account_count()
# Out:
# Account: ACC-1013
# Balance: 5000
# Account: ACC-1014
# Balance: 3000
# Total accounts: 2

# %% [markdown]
# ### Q14. Model a loyaltyaccount for banking case 1; use sample reference `ACC-1014` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance=0):
        self.account_number=account_number
        self.__balance=balance
    def deposit(self, amount):
        if amount<=0:
            raise ValueError("Deposit amount must be greater than zero")
        self.__balance+=amount
    def show_balance(self):
        print("Account:",self.account_number)
        print("Balance:",self.__balance)
class LoyaltyAccount(Account):
    def __init__(self, account_number, balance=0, points=0):
        super().__init__(account_number,balance)
        self.points=points
    def add_points(self, points):
        if points<=0:
            raise ValueError("Points must be greater than zero")
        self.points+=points
    def show_details(self):
        self.show_balance()
        print("Loyalty points:",self.points)
account=LoyaltyAccount("ACC-1014",5000)
account.deposit(1000)
account.add_points(100)
account.show_details()
# Out:
# Account: ACC-1014
# Balance: 6000
# Loyalty points: 100

# %% [markdown]
# ### Q15. Create a supplier class for banking case 1; use sample reference `ACC-1015` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance=0):
        self.account_number=account_number
        self.__balance=balance
    def show_balance(self):
        print("Account:",self.account_number)
        print("Balance:",self.__balance)
class Supplier:
    def __init__(self, supplier_id, name, account):
        self.supplier_id=supplier_id
        self.name=name
        self.account=account
    def show_details(self):
        print("Supplier ID:",self.supplier_id)
        print("Supplier name:",self.name)
        self.account.show_balance()
account=Account("ACC-1015",5000)
supplier=Supplier("SUP-1015","Ravi Suppliers",account)
supplier.show_details()
# Out:
# Supplier ID: SUP-1015
# Supplier name: Ravi Suppliers
# Account: ACC-1015
# Balance: 5000

# %% [markdown]
# ### Q16. Create a account class for banking case 2; use sample reference `ACC-1016` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance=0):
        if not isinstance(account_number,str) or account_number=="":
            raise ValueError("Invalid account reference")
        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be a number")
        if balance<0:
            raise ValueError("Balance cannot be negative")
        self.account_number=account_number
        self.__balance=balance

    def deposit(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be a number")
        if amount<=0:
            raise ValueError("Deposit amount must be greater than zero")
        self.__balance+=amount

    def withdraw(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be a number")
        if amount<=0:
            raise ValueError("Withdrawal amount must be greater than zero")
        if amount>self.__balance:
            raise ValueError("Insufficient balance")
        self.__balance-=amount

    def show_balance(self):
        print("Account:",self.account_number)
        print("Balance:",self.__balance)

account=Account("ACC-1016",5000)
account.deposit(1000)
account.withdraw(2000)
account.show_balance()
# Out:
# Account: ACC-1016
# Balance: 4000

# %% [markdown]
# ### Q17. Add an initializer to accountholder for banking case 2; use sample reference `ACC-1017` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance=0):
        self.account_number=account_number
        self.__balance=balance

    def show_balance(self):
        print("Account:",self.account_number)
        print("Balance:",self.__balance)


class AccountHolder:
    def __init__(self, name, phone, account):
        self.name=name
        self.phone=phone
        self.account=account

    def show_details(self):
        print("Name:",self.name)
        print("Phone:",self.phone)
        self.account.show_balance()


account=Account("ACC-1017",5000)
holder=AccountHolder("Ravi","9876543210",account)
holder.show_details()
# Out:
# Name: Ravi
# Phone: 9876543210
# Account: ACC-1017
# Balance: 5000

# %% [markdown]
# ### Q18. Represent an transfer object for banking case 2; use sample reference `ACC-1018` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transfer:
    def __init__(self, transfer_id, from_account, to_account, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be a number")
        if amount<=0:
            raise ValueError("Transfer amount must be greater than zero")
        self.transfer_id=transfer_id
        self.from_account=from_account
        self.to_account=to_account
        self.amount=amount

    def show_transfer(self):
        print("Transfer ID:",self.transfer_id)
        print("From Account:",self.from_account)
        print("To Account:",self.to_account)
        print("Amount:",self.amount)


transfer=Transfer("ACC-1018","ACC-1001","ACC-1002",2000)
transfer.show_transfer()
# Out:
# Transfer ID: ACC-1018
# From Account: ACC-1001
# To Account: ACC-1002
# Amount: 2000

# %% [markdown]
# ### Q19. Add a method that calculates line total for banking case 2; use sample reference `ACC-1019` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transaction:
    def __init__(self, transaction_id, quantity, unit_amount):
        self.transaction_id=transaction_id
        self.quantity=quantity
        self.unit_amount=unit_amount
    def line_total(self):
        if not isinstance(self.quantity,(int,float)):
            raise TypeError("Quantity must be a number")
        if not isinstance(self.unit_amount,(int,float)):
            raise TypeError("Unit amount must be a number")
        if self.quantity<0:
            raise ValueError("Quantity cannot be negative")
        if self.unit_amount<0:
            raise ValueError("Unit amount cannot be negative")
        return self.quantity*self.unit_amount
transaction=Transaction("ACC-1019",3,1000)
print("Transaction ID:",transaction.transaction_id)
print("Line total:",transaction.line_total())
# Out:
# Transaction ID: ACC-1019
# Line total: 3000

# %% [markdown]
# ### Q20. Use a class attribute for branch name for banking case 2; use sample reference `ACC-1020` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    branch_name="Main Branch"

    def __init__(self, account_number, balance=0):
        self.account_number=account_number
        self.__balance=balance

    def show_details(self):
        print("Account:",self.account_number)
        print("Branch:",Account.branch_name)
        print("Balance:",self.__balance)


account=Account("ACC-1020",5000)
account.show_details()
# Out:
# Account: ACC-1020
# Branch: Main Branch
# Balance: 5000

# %% [markdown]
# ### Q21. Write a readable __str__ method for banking case 2; use sample reference `ACC-1021` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance=0):
        self.account_number=account_number
        self.__balance=balance

    def __str__(self):
        return "Account: " + self.account_number + ", Balance: " + str(self.__balance)


account=Account("ACC-1021",5000)
print(account)
# Out:
# Account: ACC-1021, Balance: 5000

# %% [markdown]
# ### Q22. Compare two account references with __eq__ for banking case 2; use sample reference `ACC-1022` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance=0):
        self.account_number=account_number
        self.__balance=balance
    def __eq__(self, other):
        if not isinstance(other, Account):
            return False
        return self.account_number==other.account_number
account1=Account("ACC-1022",5000)
account2=Account("ACC-1022",3000)
print(account1==account2)
# Out:
# True

# %% [markdown]
# ### Q23. Protect a amount with a property for banking case 2; use sample reference `ACC-1023` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, amount):
        self.account_number=account_number
        self.__amount=amount

    @property
    def amount(self):
        return self.__amount

    @amount.setter
    def amount(self, value):
        if not isinstance(value,(int,float)):
            raise TypeError("Amount must be a number")
        if value<0:
            raise ValueError("Amount cannot be negative")
        self.__amount=value


account=Account("ACC-1023",5000)

print("Account:",account.account_number)
print("Amount:",account.amount)

account.amount=7000
print("Updated amount:",account.amount)
# Out:
# Account: ACC-1023
# Amount: 5000
# Updated amount: 7000

# %% [markdown]
# ### Q24. Create portfolio and add_item for banking case 2; use sample reference `ACC-1024` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Portfolio:
    def __init__(self, portfolio_id):
        self.portfolio_id=portfolio_id
        self.items=[]

    def add_item(self, item):
        if not isinstance(item,str):
            raise TypeError("Item must be a string")
        if item=="":
            raise ValueError("Item cannot be empty")
        self.items.append(item)

    def show_portfolio(self):
        print("Portfolio ID:",self.portfolio_id)
        print("Items:",self.items)


portfolio=Portfolio("ACC-1024")
portfolio.add_item("Savings Account")
portfolio.add_item("Fixed Deposit")
portfolio.show_portfolio()
# Out:
# Portfolio ID: ACC-1024
# Items: ['Savings Account', 'Fixed Deposit']

# %% [markdown]
# ### Q25. Model a branchaddress for banking case 2; use sample reference `ACC-1025` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class BranchAddress:
    def __init__(self, branch_id, street, city, state, pincode):
        if not branch_id or not street or not city or not state:
            raise ValueError("Address fields cannot be empty")
        if not isinstance(pincode,str) or not pincode.isdigit() or len(pincode)!=6:
            raise ValueError("Pincode must contain 6 digits")

        self.branch_id=branch_id
        self.street=street
        self.city=city
        self.state=state
        self.pincode=pincode

    def show_address(self):
        print("Branch ID:",self.branch_id)
        print("Street:",self.street)
        print("City:",self.city)
        print("State:",self.state)
        print("Pincode:",self.pincode)


branch=BranchAddress("ACC-1025","MG Road","Bengaluru","Karnataka","560001")
branch.show_address()
# Out:
# Branch ID: ACC-1025
# Street: MG Road
# City: Bengaluru
# State: Karnataka
# Pincode: 560001

# %% [markdown]
# ### Q26. Use a static method to validate account reference for banking case 2; use sample reference `ACC-1026` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance=0):
        self.account_number=account_number
        self.__balance=balance

    @staticmethod
    def validate_account_reference(account_number):
        if not isinstance(account_number,str):
            return False
        if account_number=="":
            return False
        if not account_number.startswith("ACC-"):
            return False
        if not account_number[4:].isdigit():
            return False
        return True

    def show_balance(self):
        print("Account:",self.account_number)
        print("Balance:",self.__balance)


account_number="ACC-1026"

if Account.validate_account_reference(account_number):
    account=Account(account_number,5000)
    account.show_balance()
else:
    print("Invalid account reference")
# Out:
# Account: ACC-1026
# Balance: 5000

# %% [markdown]
# ### Q27. Use a class method as an alternate constructor for banking case 2; use sample reference `ACC-1027` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance=0):
        self.account_number=account_number
        self.__balance=balance

    @classmethod
    def create_account(cls, account_number):
        return cls(account_number,0)

    def show_balance(self):
        print("Account:",self.account_number)
        print("Balance:",self.__balance)


account=Account.create_account("ACC-1027")
account.show_balance()
# Out:
# Account: ACC-1027
# Balance: 0

# %% [markdown]
# ### Q28. Track object count for banking case 2; use sample reference `ACC-1028` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    account_count=0

    def __init__(self, account_number, balance=0):
        self.account_number=account_number
        self.__balance=balance
        Account.account_count+=1

    @classmethod
    def show_account_count(cls):
        print("Total accounts:",cls.account_count)

    def show_balance(self):
        print("Account:",self.account_number)
        print("Balance:",self.__balance)


account1=Account("ACC-1028",5000)
account2=Account("ACC-1029",3000)

account1.show_balance()
account2.show_balance()
Account.show_account_count()
# Out:
# Account: ACC-1028
# Balance: 5000
# Account: ACC-1029
# Balance: 3000
# Total accounts: 2

# %% [markdown]
# ### Q29. Model a loyaltyaccount for banking case 2; use sample reference `ACC-1029` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance=0):
        self.account_number=account_number
        self.__balance=balance

    def deposit(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be a number")
        if amount<=0:
            raise ValueError("Deposit amount must be greater than zero")
        self.__balance+=amount

    def show_balance(self):
        print("Account:",self.account_number)
        print("Balance:",self.__balance)


class LoyaltyAccount(Account):
    def __init__(self, account_number, balance=0, points=0):
        super().__init__(account_number,balance)
        self.points=points

    def add_points(self, points):
        if not isinstance(points,int):
            raise TypeError("Points must be an integer")
        if points<=0:
            raise ValueError("Points must be greater than zero")
        self.points+=points

    def show_details(self):
        self.show_balance()
        print("Loyalty points:",self.points)


account=LoyaltyAccount("ACC-1029",5000)
account.deposit(1000)
account.add_points(100)
account.show_details()
# Out:
# Account: ACC-1029
# Balance: 6000
# Loyalty points: 100

# %% [markdown]
# ### Q30. Create a supplier class for banking case 2; use sample reference `ACC-1030` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance=0):
        self.account_number=account_number
        self.__balance=balance

    def show_balance(self):
        print("Account:",self.account_number)
        print("Balance:",self.__balance)


class Supplier:
    def __init__(self, supplier_id, name, account):
        if not isinstance(supplier_id,str) or supplier_id=="":
            raise ValueError("Invalid supplier ID")
        if not isinstance(name,str) or name=="":
            raise ValueError("Supplier name cannot be empty")
        if not isinstance(account,Account):
            raise TypeError("Account must be an Account object")

        self.supplier_id=supplier_id
        self.name=name
        self.account=account

    def show_details(self):
        print("Supplier ID:",self.supplier_id)
        print("Supplier name:",self.name)
        self.account.show_balance()


account=Account("ACC-1030",5000)
supplier=Supplier("SUP-1030","Ravi Suppliers",account)
supplier.show_details()
# Out:
# Supplier ID: SUP-1030
# Supplier name: Ravi Suppliers
# Account: ACC-1030
# Balance: 5000

# %% [markdown]
# ---
#
# ## Medium
#
# Reusable components and multi-step workflows.

# %% [markdown]
# ### Q31. Inherit perishableaccount from account for banking case 1; use sample reference `ACC-1031` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance=0):
        self.account_number=account_number
        self.__balance=balance

    def show_balance(self):
        print("Account:",self.account_number)
        print("Balance:",self.__balance)


class PerishableAccount(Account):
    def __init__(self, account_number, balance, expiry_date):
        super().__init__(account_number,balance)
        self.expiry_date=expiry_date

    def show_details(self):
        self.show_balance()
        print("Expiry date:",self.expiry_date)


account=PerishableAccount("ACC-1031",5000,"31-12-2026")
account.show_details()
# Out:
# Account: ACC-1031
# Balance: 5000
# Expiry date: 31-12-2026

# %% [markdown]
# ### Q32. Override a discount method for banking case 1; use sample reference `ACC-1032` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance):
        self.account_number=account_number
        self.balance=balance

    def discount(self, amount):
        return amount


class PremiumAccount(Account):
    def discount(self, amount):
        if amount<=0:
            raise ValueError("Amount must be greater than zero")
        return amount*0.90


account=PremiumAccount("ACC-1032",5000)
amount=1000

try:
    final_amount=account.discount(amount)
    print("Account:",account.account_number)
    print("Original amount:",amount)
    print("Discounted amount:",final_amount)
except ValueError as e:
    print("Transaction failed:",e)
# Out:
# Account: ACC-1032
# Original amount: 1000
# Discounted amount: 900.0

# %% [markdown]
# ### Q33. Use polymorphic payment processors for banking case 1; use sample reference `ACC-1033` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentProcessor:
    def pay(self, amount):
        raise NotImplementedError("Payment method must be overridden")


class UPIProcessor(PaymentProcessor):
    def pay(self, amount):
        return "UPI payment successful: " + str(amount)


class CardProcessor(PaymentProcessor):
    def pay(self, amount):
        return "Card payment successful: " + str(amount)


class NetBankingProcessor(PaymentProcessor):
    def pay(self, amount):
        return "Net banking payment successful: " + str(amount)


account="ACC-1033"
amount=1000

processors=[UPIProcessor(),CardProcessor(),NetBankingProcessor()]

try:
    if amount<=0:
        raise ValueError("Amount must be greater than zero")

    print("Account:",account)

    for processor in processors:
        print(processor.pay(amount))

except ValueError as e:
    print("Payment failed:",e)
# Out:
# Account: ACC-1033
# UPI payment successful: 1000
# Card payment successful: 1000
# Net banking payment successful: 1000

# %% [markdown]
# ### Q34. Compose transfer from transferline objects for banking case 1; use sample reference `ACC-1034` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance):
        self.account_number=account_number
        self.balance=balance

    def discount(self, amount):
        return amount


class PremiumAccount(Account):
    def discount(self, amount):
        if amount<=0:
            raise ValueError("Amount must be greater than zero")
        return amount*0.90


account=PremiumAccount("ACC-1032",5000)
amount=1000

try:
    final_amount=account.discount(amount)
    print("Account:",account.account_number)
    print("Original amount:",amount)
    print("Discounted amount:",final_amount)
except ValueError as e:
    print("Transaction failed:",e)
# Out:
# Account: ACC-1032
# Original amount: 1000
# Discounted amount: 900.0

# %% [markdown]
# ### Q35. Define an abstract paymentmethod for banking case 1; use sample reference `ACC-1035` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class TransferLine:
    def __init__(self, description, amount):
        self.description=description
        self.amount=amount

    def line_total(self):
        if not isinstance(self.amount,(int,float)):
            raise TypeError("Amount must be numeric")
        if self.amount<=0:
            raise ValueError("Amount must be greater than zero")
        return self.amount


class Transfer:
    def __init__(self, account, lines):
        self.account=account
        self.lines=lines

    def total_amount(self):
        if not self.lines:
            raise ValueError("Transfer must contain at least one line")
        total=0
        for line in self.lines:
            total=total+line.line_total()
        return total


account="ACC-1034"
balance=5000

lines=[
    TransferLine("Rent payment",1500),
    TransferLine("Electricity payment",500)
]

transfer=Transfer(account,lines)

try:
    total=transfer.total_amount()

    if total>balance:
        raise ValueError("Insufficient balance")

    balance=balance-total

    print("Account:",account)
    print("Transfer amount:",total)
    print("Final balance:",balance)

except (TypeError,ValueError) as e:
    print("Transfer failed:",e)
# Out:
# Account: ACC-1034
# Transfer amount: 2000
# Final balance: 3000

# %% [markdown]
# ### Q36. Use a dataclass for inventoryrecord for banking case 1; use sample reference `ACC-1036` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from dataclasses import dataclass

@dataclass
class InventoryRecord:
    account: str
    item_name: str
    quantity: int
    price: float

    def total_value(self):
        if not self.item_name:
            raise ValueError("Item name cannot be empty")
        if not isinstance(self.quantity,int):
            raise TypeError("Quantity must be an integer")
        if self.quantity<=0:
            raise ValueError("Quantity must be greater than zero")
        if self.price<=0:
            raise ValueError("Price must be greater than zero")
        return self.quantity*self.price


record=InventoryRecord("ACC-1036","Payment Cards",10,250)

try:
    print("Account:",record.account)
    print("Item:",record.item_name)
    print("Quantity:",record.quantity)
    print("Price:",record.price)
    print("Total inventory value:",record.total_value())

except (TypeError,ValueError) as e:
    print("Inventory failed:",e)
# Out:
# Account: ACC-1036
# Item: Payment Cards
# Quantity: 10
# Price: 250
# Total inventory value: 2500

# %% [markdown]
# ### Q37. Implement a custom iterator for portfolio for banking case 1; use sample reference `ACC-1037` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Portfolio:
    def __init__(self, account, items):
        self.account=account
        self.items=items

    def __iter__(self):
        self.index=0
        return self

    def __next__(self):
        if self.index>=len(self.items):
            raise StopIteration

        item=self.items[self.index]
        self.index+=1
        return item


account="ACC-1037"
items=["Savings Account","Current Account","Fixed Deposit"]

portfolio=Portfolio(account,items)

try:
    if not account:
        raise ValueError("Account reference cannot be empty")

    if not isinstance(items,list):
        raise TypeError("Items must be a list")

    print("Account:",account)

    for item in portfolio:
        print("Portfolio item:",item)

except (TypeError,ValueError) as e:
    print("Portfolio failed:",e)
# Out:
# Account: ACC-1037
# Portfolio item: Savings Account
# Portfolio item: Current Account
# Portfolio item: Fixed Deposit

# %% [markdown]
# ### Q38. Use multiple inheritance carefully for timestampeditem for banking case 1; use sample reference `ACC-1038` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from datetime import datetime

class BankingItem:
    def __init__(self, account, item_name):
        self.account=account
        self.item_name=item_name


class TimestampMixin:
    def add_timestamp(self):
        self.created_at=datetime.now()


class TimestampedItem(BankingItem,TimestampMixin):
    def __init__(self, account, item_name):
        BankingItem.__init__(self,account,item_name)
        self.add_timestamp()

    def show_details(self):
        print("Account:",self.account)
        print("Item:",self.item_name)
        print("Created at:",self.created_at)


try:
    item=TimestampedItem("ACC-1038","Loan Application")
    item.show_details()

except (TypeError,ValueError) as e:
    print("Item creation failed:",e)
# Out:
# Account: ACC-1038
# Item: Loan Application
# Created at: 2026-09-16 06:39:44.645614

# %% [markdown]
# ### Q39. Create a account factory for banking case 1; use sample reference `ACC-1039` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance):
        self.account_number=account_number
        self.balance=balance

    def show_details(self):
        print("Account:",self.account_number)
        print("Balance:",self.balance)


class SavingsAccount(Account):
    pass


class CurrentAccount(Account):
    pass


class AccountFactory:
    @staticmethod
    def create_account(account_type, account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        if account_type=="savings":
            return SavingsAccount(account_number,balance)

        if account_type=="current":
            return CurrentAccount(account_number,balance)

        raise ValueError("Invalid account type")


try:
    account=AccountFactory.create_account("savings","ACC-1039",5000)
    account.show_details()

except (TypeError,ValueError) as e:
    print("Account creation failed:",e)
# Out:
# Account: ACC-1039
# Balance: 5000

# %% [markdown]
# ### Q40. Apply a strategy for interest offers for banking case 1; use sample reference `ACC-1040` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class SimpleInterest:
    def calculate(self, balance):
        return balance*0.04


class PremiumInterest:
    def calculate(self, balance):
        return balance*0.06


class Account:
    def __init__(self, account_number, balance, interest_strategy):
        self.account_number=account_number
        self.balance=balance
        self.interest_strategy=interest_strategy

    def calculate_interest(self):
        return self.interest_strategy.calculate(self.balance)


account=Account("ACC-1040",5000,PremiumInterest())

try:
    if not account.account_number:
        raise ValueError("Account reference cannot be empty")

    if not isinstance(account.balance,(int,float)):
        raise TypeError("Balance must be numeric")

    if account.balance<0:
        raise ValueError("Balance cannot be negative")

    interest=account.calculate_interest()

    print("Account:",account.account_number)
    print("Balance:",account.balance)
    print("Interest offer:",interest)
    print("Balance after interest:",account.balance+interest)

except (TypeError,ValueError) as e:
    print("Interest calculation failed:",e)
# Out:
# Account: ACC-1040
# Balance: 5000
# Interest offer: 300.0
# Balance after interest: 5300.0

# %% [markdown]
# ### Q41. Encapsulate balance reservation for banking case 1; use sample reference `ACC-1041` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance):
        self.account_number=account_number
        self.__balance=balance
        self.__reserved=0

    def reserve_balance(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")
        if amount<=0:
            raise ValueError("Amount must be greater than zero")
        if amount>self.available_balance():
            raise ValueError("Insufficient available balance")

        self.__reserved=self.__reserved+amount

    def available_balance(self):
        return self.__balance-self.__reserved

    def show_details(self):
        print("Account:",self.account_number)
        print("Total balance:",self.__balance)
        print("Reserved balance:",self.__reserved)
        print("Available balance:",self.available_balance())


account=Account("ACC-1041",5000)

try:
    account.reserve_balance(1500)
    account.show_details()

except (TypeError,ValueError) as e:
    print("Reservation failed:",e)
# Out:
# Account: ACC-1041
# Total balance: 5000
# Reserved balance: 1500
# Available balance: 3500

# %% [markdown]
# ### Q42. Model aggregation between branch and employees for banking case 1; use sample reference `ACC-1042` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Employee:
    def __init__(self, name, role):
        self.name=name
        self.role=role

    def show_details(self):
        print("Employee:",self.name)
        print("Role:",self.role)


class Branch:
    def __init__(self, branch_name, employees):
        self.branch_name=branch_name
        self.employees=employees

    def show_branch(self):
        print("Account reference:",self.account)
        print("Branch:",self.branch_name)
        print("Employees:")

        for employee in self.employees:
            employee.show_details()


account="ACC-1042"

employees=[
    Employee("Ravi","Manager"),
    Employee("Anitha","Cashier"),
    Employee("Kiran","Accountant")
]

branch=Branch("Bengaluru Main Branch",employees)
branch.account=account

try:
    if not account:
        raise ValueError("Account reference cannot be empty")

    if not isinstance(employees,list):
        raise TypeError("Employees must be a list")

    branch.show_branch()

except (TypeError,ValueError) as e:
    print("Branch creation failed:",e)
# Out:
# Account reference: ACC-1042
# Branch: Bengaluru Main Branch
# Employees:
# Employee: Ravi
# Role: Manager
# Employee: Anitha
# Role: Cashier
# Employee: Kiran
# Role: Accountant

# %% [markdown]
# ### Q43. Serialize an transfer to a dictionary for banking case 1; use sample reference `ACC-1043` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transfer:
    def __init__(self, account, receiver, amount):
        self.account=account
        self.receiver=receiver
        self.amount=amount

    def to_dictionary(self):
        if not self.account:
            raise ValueError("Account reference cannot be empty")
        if not self.receiver:
            raise ValueError("Receiver cannot be empty")
        if not isinstance(self.amount,(int,float)):
            raise TypeError("Amount must be numeric")
        if self.amount<=0:
            raise ValueError("Amount must be greater than zero")

        return {"account":self.account,"receiver":self.receiver,"amount":self.amount}


transfer=Transfer("ACC-1043","ACC-2043",2000)

try:
    transfer_data=transfer.to_dictionary()
    print("Serialized transfer:",transfer_data)

except (TypeError,ValueError) as e:
    print("Serialization failed:",e)
# Out:
# Serialized transfer: {'account': 'ACC-1043', 'receiver': 'ACC-2043', 'amount': 2000}

# %% [markdown]
# ### Q44. Implement a repository abstraction for banking case 1; use sample reference `ACC-1044` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from abc import ABC, abstractmethod

class AccountRepository(ABC):
    @abstractmethod
    def save(self, account):
        pass

    @abstractmethod
    def find(self, account_number):
        pass


class MemoryAccountRepository(AccountRepository):
    def __init__(self):
        self.accounts={}

    def save(self, account):
        if not account:
            raise ValueError("Account cannot be empty")
        self.accounts[account["account_number"]]=account

    def find(self, account_number):
        if not account_number:
            raise ValueError("Account reference cannot be empty")
        return self.accounts.get(account_number)


repository=MemoryAccountRepository()

account={"account_number":"ACC-1044","balance":5000}

try:
    repository.save(account)

    print("Saved account:",repository.find("ACC-1044"))

except (TypeError,ValueError) as e:
    print("Repository operation failed:",e)
# Out:
# Saved account: {'account_number': 'ACC-1044', 'balance': 5000}

# %% [markdown]
# ### Q45. Apply dependency injection to checkout for banking case 1; use sample reference `ACC-1045` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentService:
    def pay(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")
        if amount<=0:
            raise ValueError("Amount must be greater than zero")
        return "Payment successful"


class Checkout:
    def __init__(self, account, payment_service):
        self.account=account
        self.payment_service=payment_service

    def complete_checkout(self, amount):
        return self.payment_service.pay(amount)


account="ACC-1045"
amount=1000
payment_service=PaymentService()
checkout=Checkout(account,payment_service)

try:
    result=checkout.complete_checkout(amount)
    print("Account:",account)
    print(result)
    print("Amount paid:",amount)

except (TypeError,ValueError) as e:
    print("Checkout failed:",e)
# Out:
# Account: ACC-1045
# Payment successful
# Amount paid: 1000

# %% [markdown]
# ### Q46. Inherit perishableaccount from account for banking case 2; use sample reference `ACC-1046` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance):
        self.account_number=account_number
        self.__balance=balance

    def show_balance(self):
        print("Account:",self.account_number)
        print("Balance:",self.__balance)


class PerishableAccount(Account):
    def __init__(self, account_number, balance, expiry_date):
        super().__init__(account_number,balance)
        self.expiry_date=expiry_date

    def show_details(self):
        self.show_balance()
        print("Expiry date:",self.expiry_date)


account=PerishableAccount("ACC-1046",7500,"31-12-2027")
account.show_details()
# Out:
# Account: ACC-1046
# Balance: 7500
# Expiry date: 31-12-2027

# %% [markdown]
# ### Q47. Override a discount method for banking case 2; use sample reference `ACC-1047` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance):
        self.account_number=account_number
        self.balance=balance

    def discount(self, amount):
        return amount


class PremiumAccount(Account):
    def discount(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")
        if amount<=0:
            raise ValueError("Amount must be greater than zero")
        return amount*0.85


account=PremiumAccount("ACC-1047",7500)
amount=2000

try:
    discounted_amount=account.discount(amount)

    print("Account:",account.account_number)
    print("Original amount:",amount)
    print("Discounted amount:",discounted_amount)

except (TypeError,ValueError) as e:
    print("Discount failed:",e)
# Out:
# Account: ACC-1047
# Original amount: 2000
# Discounted amount: 1700.0

# %% [markdown]
# ### Q48. Use polymorphic payment processors for banking case 2; use sample reference `ACC-1048` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentProcessor:
    def pay(self, amount):
        raise NotImplementedError("Payment method must be overridden")


class UPIProcessor(PaymentProcessor):
    def pay(self, amount):
        return "UPI payment successful: " + str(amount)


class CardProcessor(PaymentProcessor):
    def pay(self, amount):
        return "Card payment successful: " + str(amount)


class NetBankingProcessor(PaymentProcessor):
    def pay(self, amount):
        return "Net banking payment successful: " + str(amount)


account="ACC-1048"
amount=2000
processors=[UPIProcessor(),CardProcessor(),NetBankingProcessor()]

try:
    if not account:
        raise ValueError("Account reference cannot be empty")

    if not isinstance(amount,(int,float)):
        raise TypeError("Amount must be numeric")

    if amount<=0:
        raise ValueError("Amount must be greater than zero")

    print("Account:",account)

    for processor in processors:
        print(processor.pay(amount))

except (TypeError,ValueError) as e:
    print("Payment failed:",e)
# Out:
# Account: ACC-1048
# UPI payment successful: 2000
# Card payment successful: 2000
# Net banking payment successful: 2000

# %% [markdown]
# ### Q49. Compose transfer from transferline objects for banking case 2; use sample reference `ACC-1049` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class TransferLine:
    def __init__(self, description, amount):
        self.description=description
        self.amount=amount

    def line_total(self):
        if not isinstance(self.amount,(int,float)):
            raise TypeError("Amount must be numeric")
        if self.amount<=0:
            raise ValueError("Amount must be greater than zero")
        return self.amount


class Transfer:
    def __init__(self, account, lines):
        self.account=account
        self.lines=lines

    def total_amount(self):
        if not self.lines:
            raise ValueError("Transfer must contain at least one line")

        total=0

        for line in self.lines:
            total=total+line.line_total()

        return total


account="ACC-1049"
balance=7500

lines=[
    TransferLine("Rent payment",2000),
    TransferLine("Electricity payment",1000),
    TransferLine("Internet payment",500)
]

transfer=Transfer(account,lines)

try:
    if not account:
        raise ValueError("Account reference cannot be empty")

    if not isinstance(lines,list):
        raise TypeError("Transfer lines must be a list")

    total=transfer.total_amount()

    if total>balance:
        raise ValueError("Insufficient balance")

    balance=balance-total

    print("Account:",account)
    print("Transfer amount:",total)
    print("Final balance:",balance)

except (TypeError,ValueError) as e:
    print("Transfer failed:",e)
# Out:
# Account: ACC-1049
# Transfer amount: 3500
# Final balance: 4000

# %% [markdown]
# ### Q50. Define an abstract paymentmethod for banking case 2; use sample reference `ACC-1050` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from abc import ABC, abstractmethod

class PaymentMethod(ABC):
    @abstractmethod
    def pay(self, amount):
        pass


class UPI(PaymentMethod):
    def pay(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")
        if amount<=0:
            raise ValueError("Amount must be greater than zero")
        return "UPI payment successful: " + str(amount)


class Card(PaymentMethod):
    def pay(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")
        if amount<=0:
            raise ValueError("Amount must be greater than zero")
        return "Card payment successful: " + str(amount)


account="ACC-1050"
amount=2500

try:
    payment_methods=[UPI(),Card()]

    if not account:
        raise ValueError("Account reference cannot be empty")

    print("Account:",account)

    for method in payment_methods:
        print(method.pay(amount))

except (TypeError,ValueError) as e:
    print("Payment failed:",e)
# Out:
# Account: ACC-1050
# UPI payment successful: 2500
# Card payment successful: 2500

# %% [markdown]
# ### Q51. Use a dataclass for inventoryrecord for banking case 2; use sample reference `ACC-1051` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from dataclasses import dataclass

@dataclass
class InventoryRecord:
    account: str
    item_name: str
    quantity: int
    price: float

    def total_value(self):
        if not self.item_name:
            raise ValueError("Item name cannot be empty")
        if not isinstance(self.quantity,int):
            raise TypeError("Quantity must be an integer")
        if self.quantity<=0:
            raise ValueError("Quantity must be greater than zero")
        if not isinstance(self.price,(int,float)):
            raise TypeError("Price must be numeric")
        if self.price<=0:
            raise ValueError("Price must be greater than zero")

        return self.quantity*self.price


record=InventoryRecord("ACC-1051","Cheque Books",20,150)

try:
    if not record.account:
        raise ValueError("Account reference cannot be empty")

    print("Account:",record.account)
    print("Item:",record.item_name)
    print("Quantity:",record.quantity)
    print("Price:",record.price)
    print("Total inventory value:",record.total_value())

except (TypeError,ValueError) as e:
    print("Inventory failed:",e)
# Out:
# Account: ACC-1051
# Item: Cheque Books
# Quantity: 20
# Price: 150
# Total inventory value: 3000

# %% [markdown]
# ### Q52. Implement a custom iterator for portfolio for banking case 2; use sample reference `ACC-1052` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Portfolio:
    def __init__(self, account, items):
        self.account=account
        self.items=items

    def __iter__(self):
        self.index=0
        return self

    def __next__(self):
        if self.index>=len(self.items):
            raise StopIteration

        item=self.items[self.index]
        self.index+=1
        return item


account="ACC-1052"
items=["Savings Account","Fixed Deposit","Recurring Deposit"]

portfolio=Portfolio(account,items)

try:
    if not account:
        raise ValueError("Account reference cannot be empty")

    if not isinstance(items,list):
        raise TypeError("Items must be a list")

    print("Account:",account)

    for item in portfolio:
        print("Portfolio item:",item)

except (TypeError,ValueError) as e:
    print("Portfolio failed:",e)
# Out:
# Account: ACC-1052
# Portfolio item: Savings Account
# Portfolio item: Fixed Deposit
# Portfolio item: Recurring Deposit

# %% [markdown]
# ### Q53. Use multiple inheritance carefully for timestampeditem for banking case 2; use sample reference `ACC-1053` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from datetime import datetime

class BankingItem:
    def __init__(self, account, item_name):
        self.account=account
        self.item_name=item_name


class TimestampMixin:
    def add_timestamp(self):
        self.created_at=datetime.now()


class TimestampedItem(BankingItem,TimestampMixin):
    def __init__(self, account, item_name):
        if not account:
            raise ValueError("Account reference cannot be empty")
        if not item_name:
            raise ValueError("Item name cannot be empty")

        BankingItem.__init__(self,account,item_name)
        self.add_timestamp()

    def show_details(self):
        print("Account:",self.account)
        print("Item:",self.item_name)
        print("Created at:",self.created_at)


try:
    item=TimestampedItem("ACC-1053","Loan Application")
    item.show_details()

except (TypeError,ValueError) as e:
    print("Item creation failed:",e)
# Out:
# Account: ACC-1053
# Item: Loan Application
# Created at: 2026-09-16 16:06:49.024326

# %% [markdown]
# ### Q54. Create a account factory for banking case 2; use sample reference `ACC-1054` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance):
        self.account_number=account_number
        self.balance=balance

    def show_details(self):
        print("Account:",self.account_number)
        print("Balance:",self.balance)


class SavingsAccount(Account):
    pass


class CurrentAccount(Account):
    pass


class AccountFactory:
    @staticmethod
    def create_account(account_type, account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        if account_type=="savings":
            return SavingsAccount(account_number,balance)

        if account_type=="current":
            return CurrentAccount(account_number,balance)

        raise ValueError("Invalid account type")


try:
    account=AccountFactory.create_account("current","ACC-1054",8000)
    account.show_details()

except (TypeError,ValueError) as e:
    print("Account creation failed:",e)
# Out:
# Account: ACC-1054
# Balance: 8000

# %% [markdown]
# ### Q55. Apply a strategy for interest offers for banking case 2; use sample reference `ACC-1055` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class SimpleInterest:
    def calculate(self, balance):
        return balance*0.04


class PremiumInterest:
    def calculate(self, balance):
        return balance*0.06


class Account:
    def __init__(self, account_number, balance, interest_strategy):
        self.account_number=account_number
        self.balance=balance
        self.interest_strategy=interest_strategy

    def calculate_interest(self):
        return self.interest_strategy.calculate(self.balance)


account=Account("ACC-1055",8000,SimpleInterest())

try:
    if not account.account_number:
        raise ValueError("Account reference cannot be empty")

    if not isinstance(account.balance,(int,float)):
        raise TypeError("Balance must be numeric")

    if account.balance<0:
        raise ValueError("Balance cannot be negative")

    interest=account.calculate_interest()

    print("Account:",account.account_number)
    print("Balance:",account.balance)
    print("Interest offer:",interest)
    print("Balance after interest:",account.balance+interest)

except (TypeError,ValueError) as e:
    print("Interest calculation failed:",e)
# Out:
# Account: ACC-1055
# Balance: 8000
# Interest offer: 320.0
# Balance after interest: 8320.0

# %% [markdown]
# ### Q56. Encapsulate balance reservation for banking case 2; use sample reference `ACC-1056` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance):
        self.account_number=account_number
        self.__balance=balance
        self.__reserved=0

    def reserve_balance(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>self.available_balance():
            raise ValueError("Insufficient available balance")

        self.__reserved=self.__reserved+amount

    def available_balance(self):
        return self.__balance-self.__reserved

    def show_details(self):
        print("Account:",self.account_number)
        print("Total balance:",self.__balance)
        print("Reserved balance:",self.__reserved)
        print("Available balance:",self.available_balance())


account=Account("ACC-1056",7500)

try:
    account.reserve_balance(2500)
    account.show_details()

except (TypeError,ValueError) as e:
    print("Reservation failed:",e)
# Out:
# Account: ACC-1056
# Total balance: 7500
# Reserved balance: 2500
# Available balance: 5000

# %% [markdown]
# ### Q57. Model aggregation between branch and employees for banking case 2; use sample reference `ACC-1057` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Employee:
    def __init__(self, name, role):
        self.name=name
        self.role=role

    def show_details(self):
        print("Employee:",self.name)
        print("Role:",self.role)


class Branch:
    def __init__(self, account, branch_name, employees):
        self.account=account
        self.branch_name=branch_name
        self.employees=employees

    def show_branch(self):
        print("Account reference:",self.account)
        print("Branch:",self.branch_name)
        print("Employees:")

        for employee in self.employees:
            employee.show_details()


account="ACC-1057"

employees=[
    Employee("Lakshman Reddy","Manager"),
    Employee("Anitha","Cashier"),
    Employee("Kiran","Accountant")
]

branch=Branch(account,"Bengaluru Main Branch",employees)

try:
    if not account:
        raise ValueError("Account reference cannot be empty")

    if not isinstance(employees,list):
        raise TypeError("Employees must be a list")

    if not employees:
        raise ValueError("Branch must have at least one employee")

    branch.show_branch()

except (TypeError,ValueError) as e:
    print("Branch creation failed:",e)
# Out:
# Account reference: ACC-1057
# Branch: Bengaluru Main Branch
# Employees:
# Employee: Lakshman Reddy
# Role: Manager
# Employee: Anitha
# Role: Cashier
# Employee: Kiran
# Role: Accountant

# %% [markdown]
# ### Q58. Serialize an transfer to a dictionary for banking case 2; use sample reference `ACC-1058` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transfer:
    def __init__(self, account, receiver, amount):
        self.account=account
        self.receiver=receiver
        self.amount=amount

    def to_dictionary(self):
        if not self.account:
            raise ValueError("Account reference cannot be empty")

        if not self.receiver:
            raise ValueError("Receiver cannot be empty")

        if not isinstance(self.amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if self.amount<=0:
            raise ValueError("Amount must be greater than zero")

        return {"account":self.account,"receiver":self.receiver,"amount":self.amount}


transfer=Transfer("ACC-1058","ACC-2058",3000)

try:
    transfer_data=transfer.to_dictionary()
    print("Serialized transfer:",transfer_data)

except (TypeError,ValueError) as e:
    print("Serialization failed:",e)
# Out:
# Serialized transfer: {'account': 'ACC-1058', 'receiver': 'ACC-2058', 'amount': 3000}

# %% [markdown]
# ### Q59. Implement a repository abstraction for banking case 2; use sample reference `ACC-1059` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from abc import ABC, abstractmethod

class AccountRepository(ABC):
    @abstractmethod
    def save(self, account):
        pass

    @abstractmethod
    def find(self, account_number):
        pass


class MemoryAccountRepository(AccountRepository):
    def __init__(self):
        self.accounts={}

    def save(self, account):
        if not isinstance(account,dict):
            raise TypeError("Account must be a dictionary")

        if not account.get("account_number"):
            raise ValueError("Account reference cannot be empty")

        if not isinstance(account.get("balance"),(int,float)):
            raise TypeError("Balance must be numeric")

        if account["balance"]<0:
            raise ValueError("Balance cannot be negative")

        self.accounts[account["account_number"]]=account

    def find(self, account_number):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        return self.accounts.get(account_number)


repository=MemoryAccountRepository()
account={"account_number":"ACC-1059","balance":8500}

try:
    repository.save(account)
    print("Saved account:",repository.find("ACC-1059"))

except (TypeError,ValueError) as e:
    print("Repository operation failed:",e)
# Out:
# Saved account: {'account_number': 'ACC-1059', 'balance': 8500}

# %% [markdown]
# ### Q60. Apply dependency injection to checkout for banking case 2; use sample reference `ACC-1060` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentService:
    def pay(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        return "Payment successful"


class Checkout:
    def __init__(self, account, payment_service):
        self.account=account
        self.payment_service=payment_service

    def complete_checkout(self, amount):
        return self.payment_service.pay(amount)


account="ACC-1060"
amount=2500
payment_service=PaymentService()
checkout=Checkout(account,payment_service)

try:
    if not account:
        raise ValueError("Account reference cannot be empty")

    result=checkout.complete_checkout(amount)

    print("Account:",account)
    print(result)
    print("Amount paid:",amount)

except (TypeError,ValueError) as e:
    print("Checkout failed:",e)
# Out:
# Account: ACC-1060
# Payment successful
# Amount paid: 2500

# %% [markdown]
# ### Q61. Inherit perishableaccount from account for banking case 3; use sample reference `ACC-1061` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        self.account_number=account_number
        self.__balance=balance

    def show_balance(self):
        print("Account:",self.account_number)
        print("Balance:",self.__balance)


class PerishableAccount(Account):
    def __init__(self, account_number, balance, expiry_date):
        super().__init__(account_number,balance)

        if not expiry_date:
            raise ValueError("Expiry date cannot be empty")

        self.expiry_date=expiry_date

    def show_details(self):
        self.show_balance()
        print("Expiry date:",self.expiry_date)


try:
    account=PerishableAccount("ACC-1061",9000,"31-12-2028")
    account.show_details()

except (TypeError,ValueError) as e:
    print("Account creation failed:",e)
# Out:
# Account: ACC-1061
# Balance: 9000
# Expiry date: 31-12-2028

# %% [markdown]
# ### Q62. Override a discount method for banking case 3; use sample reference `ACC-1062` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        self.account_number=account_number
        self.balance=balance

    def discount(self, amount):
        return amount


class PremiumAccount(Account):
    def discount(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        return amount*0.80


account=PremiumAccount("ACC-1062",10000)
amount=3000

try:
    discounted_amount=account.discount(amount)

    print("Account:",account.account_number)
    print("Original amount:",amount)
    print("Discounted amount:",discounted_amount)

except (TypeError,ValueError) as e:
    print("Discount failed:",e)
# Out:
# Account: ACC-1062
# Original amount: 3000
# Discounted amount: 2400.0

# %% [markdown]
# ### Q63. Use polymorphic payment processors for banking case 3; use sample reference `ACC-1063` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PaymentProcessor:
    def pay(self, amount):
        raise NotImplementedError("Payment method must be overridden")


class UPIProcessor(PaymentProcessor):
    def pay(self, amount):
        return "UPI payment successful: " + str(amount)


class CardProcessor(PaymentProcessor):
    def pay(self, amount):
        return "Card payment successful: " + str(amount)


class NetBankingProcessor(PaymentProcessor):
    def pay(self, amount):
        return "Net banking payment successful: " + str(amount)


account="ACC-1063"
amount=3500
processors=[UPIProcessor(),CardProcessor(),NetBankingProcessor()]

try:
    if not account:
        raise ValueError("Account reference cannot be empty")

    if not isinstance(amount,(int,float)):
        raise TypeError("Amount must be numeric")

    if amount<=0:
        raise ValueError("Amount must be greater than zero")

    if not processors:
        raise ValueError("At least one payment processor is required")

    print("Account:",account)

    for processor in processors:
        print(processor.pay(amount))

except (TypeError,ValueError) as e:
    print("Payment failed:",e)
# Out:
# Account: ACC-1063
# UPI payment successful: 3500
# Card payment successful: 3500
# Net banking payment successful: 3500

# %% [markdown]
# ### Q64. Compose transfer from transferline objects for banking case 3; use sample reference `ACC-1064` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class TransferLine:
    def __init__(self, description, amount):
        self.description=description
        self.amount=amount

    def line_total(self):
        if not isinstance(self.amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if self.amount<=0:
            raise ValueError("Amount must be greater than zero")

        return self.amount


class Transfer:
    def __init__(self, account, lines):
        self.account=account
        self.lines=lines

    def total_amount(self):
        if not self.lines:
            raise ValueError("Transfer must contain at least one line")

        total=0

        for line in self.lines:
            total=total+line.line_total()

        return total


account="ACC-1064"
balance=10000

lines=[
    TransferLine("Rent payment",3000),
    TransferLine("Electricity payment",1500),
    TransferLine("Internet payment",500)
]

transfer=Transfer(account,lines)

try:
    if not account:
        raise ValueError("Account reference cannot be empty")

    if not isinstance(lines,list):
        raise TypeError("Transfer lines must be a list")

    total=transfer.total_amount()

    if total>balance:
        raise ValueError("Insufficient balance")

    balance=balance-total

    print("Account:",account)
    print("Transfer amount:",total)
    print("Final balance:",balance)

except (TypeError,ValueError) as e:
    print("Transfer failed:",e)
# Out:
# Account: ACC-1064
# Transfer amount: 5000
# Final balance: 5000

# %% [markdown]
# ### Q65. Define an abstract paymentmethod for banking case 3; use sample reference `ACC-1065` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from abc import ABC, abstractmethod

class PaymentMethod(ABC):
    @abstractmethod
    def pay(self, amount):
        pass


class UPI(PaymentMethod):
    def pay(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        return "UPI payment successful: " + str(amount)


class Card(PaymentMethod):
    def pay(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        return "Card payment successful: " + str(amount)


account="ACC-1065"
amount=4000

try:
    if not account:
        raise ValueError("Account reference cannot be empty")

    payment_methods=[UPI(),Card()]

    print("Account:",account)

    for method in payment_methods:
        print(method.pay(amount))

except (TypeError,ValueError) as e:
    print("Payment failed:",e)
# Out:
# Account: ACC-1065
# UPI payment successful: 4000
# Card payment successful: 4000

# %% [markdown]
# ### Q66. Use a dataclass for inventoryrecord for banking case 3; use sample reference `ACC-1066` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from dataclasses import dataclass

@dataclass
class InventoryRecord:
    account: str
    item_name: str
    quantity: int
    price: float

    def total_value(self):
        if not self.item_name:
            raise ValueError("Item name cannot be empty")

        if not isinstance(self.quantity,int):
            raise TypeError("Quantity must be an integer")

        if self.quantity<=0:
            raise ValueError("Quantity must be greater than zero")

        if not isinstance(self.price,(int,float)):
            raise TypeError("Price must be numeric")

        if self.price<=0:
            raise ValueError("Price must be greater than zero")

        return self.quantity*self.price


record=InventoryRecord("ACC-1066","Debit Cards",30,200)

try:
    if not record.account:
        raise ValueError("Account reference cannot be empty")

    print("Account:",record.account)
    print("Item:",record.item_name)
    print("Quantity:",record.quantity)
    print("Price:",record.price)
    print("Total inventory value:",record.total_value())

except (TypeError,ValueError) as e:
    print("Inventory failed:",e)
# Out:
# Account: ACC-1066
# Item: Debit Cards
# Quantity: 30
# Price: 200
# Total inventory value: 6000

# %% [markdown]
# ### Q67. Implement a custom iterator for portfolio for banking case 3; use sample reference `ACC-1067` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Portfolio:
    def __init__(self, account, items):
        self.account=account
        self.items=items

    def __iter__(self):
        self.index=0
        return self

    def __next__(self):
        if self.index>=len(self.items):
            raise StopIteration

        item=self.items[self.index]
        self.index=self.index+1
        return item


account="ACC-1067"
items=["Savings Account","Fixed Deposit","Recurring Deposit","Loan Account"]

portfolio=Portfolio(account,items)

try:
    if not account:
        raise ValueError("Account reference cannot be empty")

    if not isinstance(items,list):
        raise TypeError("Items must be a list")

    print("Account:",account)

    for item in portfolio:
        print("Portfolio item:",item)

except (TypeError,ValueError) as e:
    print("Portfolio failed:",e)
# Out:
# Account: ACC-1067
# Portfolio item: Savings Account
# Portfolio item: Fixed Deposit
# Portfolio item: Recurring Deposit
# Portfolio item: Loan Account

# %% [markdown]
# ### Q68. Use multiple inheritance carefully for timestampeditem for banking case 3; use sample reference `ACC-1068` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from datetime import datetime

class BankingItem:
    def __init__(self, account, item_name):
        if not account:
            raise ValueError("Account reference cannot be empty")

        if not item_name:
            raise ValueError("Item name cannot be empty")

        self.account=account
        self.item_name=item_name


class TimestampMixin:
    def add_timestamp(self):
        self.created_at=datetime.now()


class TimestampedItem(BankingItem,TimestampMixin):
    def __init__(self, account, item_name):
        BankingItem.__init__(self,account,item_name)
        self.add_timestamp()

    def show_details(self):
        print("Account:",self.account)
        print("Item:",self.item_name)
        print("Created at:",self.created_at)


try:
    item=TimestampedItem("ACC-1068","Loan Application")
    item.show_details()

except (TypeError,ValueError) as e:
    print("Item creation failed:",e)
# Out:
# Account: ACC-1068
# Item: Loan Application
# Created at: 2026-09-17 08:53:06.010906

# %% [markdown]
# ### Q69. Create a account factory for banking case 3; use sample reference `ACC-1069` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance):
        self.account_number=account_number
        self.balance=balance

    def show_details(self):
        print("Account:",self.account_number)
        print("Balance:",self.balance)


class SavingsAccount(Account):
    pass


class CurrentAccount(Account):
    pass


class AccountFactory:
    @staticmethod
    def create_account(account_type, account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        if account_type=="savings":
            return SavingsAccount(account_number,balance)

        if account_type=="current":
            return CurrentAccount(account_number,balance)

        raise ValueError("Invalid account type")


try:
    account=AccountFactory.create_account("savings","ACC-1069",12000)
    account.show_details()

except (TypeError,ValueError) as e:
    print("Account creation failed:",e)
# Out:
# Account: ACC-1069
# Balance: 12000

# %% [markdown]
# ### Q70. Apply a strategy for interest offers for banking case 3; use sample reference `ACC-1070` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class SimpleInterest:
    def calculate(self, balance):
        return balance*0.04


class PremiumInterest:
    def calculate(self, balance):
        return balance*0.06


class Account:
    def __init__(self, account_number, balance, interest_strategy):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        self.account_number=account_number
        self.__balance=balance
        self.interest_strategy=interest_strategy

    def calculate_interest(self):
        if not hasattr(self.interest_strategy,"calculate"):
            raise TypeError("Invalid interest strategy")

        return self.interest_strategy.calculate(self.__balance)

    def show_details(self):
        interest=self.calculate_interest()

        print("Account:",self.account_number)
        print("Balance:",self.__balance)
        print("Interest offer:",interest)
        print("Balance after interest:",self.__balance+interest)


try:
    account=Account("ACC-1070",15000,PremiumInterest())
    account.show_details()

except (TypeError,ValueError) as e:
    print("Interest calculation failed:",e)
# Out:
# Account: ACC-1070
# Balance: 15000
# Interest offer: 900.0
# Balance after interest: 15900.0

# %% [markdown]
# ---
#
# ## Difficult
#
# Architecture, edge cases, and end-to-end banking systems.

# %% [markdown]
# ### Q71. Design an extensible pricing engine for banking case 1; use sample reference `ACC-1071` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PricingRule:
    def calculate(self, amount):
        raise NotImplementedError("Pricing rule must be implemented")


class RegularPricing(PricingRule):
    def calculate(self, amount):
        return amount


class PremiumPricing(PricingRule):
    def calculate(self, amount):
        return amount*0.90


class PricingEngine:
    def __init__(self, pricing_rule):
        self.pricing_rule=pricing_rule

    def final_price(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if not isinstance(self.pricing_rule,PricingRule):
            raise TypeError("Invalid pricing rule")

        return self.pricing_rule.calculate(amount)


account="ACC-1071"
amount=5000
engine=PricingEngine(PremiumPricing())

try:
    if not account:
        raise ValueError("Account reference cannot be empty")

    final_amount=engine.final_price(amount)

    print("Account:",account)
    print("Original amount:",amount)
    print("Final price:",final_amount)

except (TypeError,ValueError) as e:
    print("Pricing failed:",e)
# Out:
# Account: ACC-1071
# Original amount: 5000
# Final price: 4500.0

# %% [markdown]
# ### Q72. Implement an observer for low balance for banking case 1; use sample reference `ACC-1072` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class LowBalanceObserver:
    def update(self, account_number, balance):
        print("Alert:",account_number,"has low balance of",balance)


class Account:
    def __init__(self, account_number, balance, low_balance_limit):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        if not isinstance(low_balance_limit,(int,float)):
            raise TypeError("Low balance limit must be numeric")

        if low_balance_limit<0:
            raise ValueError("Low balance limit cannot be negative")

        self.account_number=account_number
        self.__balance=balance
        self.low_balance_limit=low_balance_limit
        self.observers=[]

    def add_observer(self, observer):
        self.observers.append(observer)

    def withdraw(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance=self.__balance-amount

        if self.__balance<=self.low_balance_limit:
            for observer in self.observers:
                observer.update(self.account_number,self.__balance)

    def show_balance(self):
        print("Account:",self.account_number)
        print("Final balance:",self.__balance)


try:
    account=Account("ACC-1072",5000,2000)
    observer=LowBalanceObserver()

    account.add_observer(observer)
    account.withdraw(3200)
    account.show_balance()

except (TypeError,ValueError) as e:
    print("Banking operation failed:",e)
# Out:
# Alert: ACC-1072 has low balance of 1800
# Account: ACC-1072
# Final balance: 1800

# %% [markdown]
# ### Q73. Build a state machine for transfer status for banking case 1; use sample reference `ACC-1073` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transfer:
    valid_states=["Pending","Processing","Completed","Failed"]

    def __init__(self, account, amount):
        if not account:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        self.account=account
        self.amount=amount
        self.status="Pending"

    def change_status(self, new_status):
        if new_status not in self.valid_states:
            raise ValueError("Invalid transfer status")

        allowed_transitions={
            "Pending":["Processing","Failed"],
            "Processing":["Completed","Failed"],
            "Completed":[],
            "Failed":[]
        }

        if new_status not in allowed_transitions[self.status]:
            raise ValueError("Invalid status transition")

        self.status=new_status

    def show_details(self):
        print("Account:",self.account)
        print("Transfer amount:",self.amount)
        print("Transfer status:",self.status)


try:
    transfer=Transfer("ACC-1073",4000)

    transfer.change_status("Processing")
    transfer.change_status("Completed")
    transfer.show_details()

except (TypeError,ValueError) as e:
    print("Transfer failed:",e)
# Out:
# Account: ACC-1073
# Transfer amount: 4000
# Transfer status: Completed

# %% [markdown]
# ### Q74. Create an immutable money value object for banking case 1; use sample reference `ACC-1074` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from dataclasses import dataclass
from decimal import Decimal

@dataclass(frozen=True)
class Money:
    amount: Decimal
    currency: str

    def __post_init__(self):
        if not isinstance(self.amount,Decimal):
            raise TypeError("Amount must be a Decimal")

        if self.amount<0:
            raise ValueError("Amount cannot be negative")

        if not self.currency:
            raise ValueError("Currency cannot be empty")

    def add(self, other):
        if self.currency!=other.currency:
            raise ValueError("Currencies must match")

        return Money(self.amount+other.amount,self.currency)


account="ACC-1074"

try:
    balance=Money(Decimal("5000.00"),"INR")
    deposit=Money(Decimal("1500.00"),"INR")
    final_balance=balance.add(deposit)

    print("Account:",account)
    print("Opening balance:",balance.amount,balance.currency)
    print("Deposit:",deposit.amount,deposit.currency)
    print("Final balance:",final_balance.amount,final_balance.currency)

except (TypeError,ValueError) as e:
    print("Money operation failed:",e)
# Out:
# Account: ACC-1074
# Opening balance: 5000.00 INR
# Deposit: 1500.00 INR
# Final balance: 6500.00 INR

# %% [markdown]
# ### Q75. Implement a unit-of-work transaction for banking case 1; use sample reference `ACC-1075` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        self.account_number=account_number
        self.__balance=balance

    def withdraw(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance=self.__balance-amount

    def deposit(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        self.__balance=self.__balance+amount

    def get_balance(self):
        return self.__balance


class UnitOfWork:
    def __init__(self, accounts):
        self.accounts=accounts
        self.old_balances={account.account_number:account.get_balance() for account in accounts}

    def __enter__(self):
        print("Transaction started")
        return self

    def __exit__(self, exc_type, exc_value, traceback):
        if exc_type:
            for account in self.accounts:
                account._Account__balance=self.old_balances[account.account_number]

            print("Transaction rolled back")
            print("Reason:",exc_value)
            return True

        print("Transaction committed")


try:
    account1=Account("ACC-1075",5000)
    account2=Account("ACC-2075",3000)

    with UnitOfWork([account1,account2]):
        account1.withdraw(2000)
        account2.deposit(2000)

    print("Account:",account1.account_number)
    print("Final balance:",account1.get_balance())
    print("Account:",account2.account_number)
    print("Final balance:",account2.get_balance())

except (TypeError,ValueError) as e:
    print("Transaction failed:",e)
# Out:
# Transaction started
# Transaction committed
# Account: ACC-1075
# Final balance: 3000
# Account: ACC-2075
# Final balance: 5000

# %% [markdown]
# ### Q76. Separate domain and infrastructure layers for banking case 1; use sample reference `ACC-1076` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        self.account_number=account_number
        self.__balance=balance

    def withdraw(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance=self.__balance-amount

    def get_balance(self):
        return self.__balance


class AccountRepository:
    def __init__(self):
        self.accounts={}

    def save(self, account):
        self.accounts[account.account_number]=account

    def find(self, account_number):
        return self.accounts.get(account_number)


class BankingService:
    def __init__(self, repository):
        self.repository=repository

    def withdraw_money(self, account_number, amount):
        account=self.repository.find(account_number)

        if account is None:
            raise ValueError("Account not found")

        account.withdraw(amount)
        self.repository.save(account)

        return account.get_balance()


try:
    account=Account("ACC-1076",6000)

    repository=AccountRepository()
    repository.save(account)

    service=BankingService(repository)
    final_balance=service.withdraw_money("ACC-1076",1500)

    print("Account:",account.account_number)
    print("Final balance:",final_balance)

except (TypeError,ValueError) as e:
    print("Banking operation failed:",e)
# Out:
# Account: ACC-1076
# Final balance: 4500

# %% [markdown]
# ### Q77. Design a plugin-ready payment architecture for banking case 1; use sample reference `ACC-1077` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from abc import ABC, abstractmethod

class Account:
    def __init__(self, account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        self.account_number=account_number
        self.__balance=balance

    def withdraw(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance=self.__balance-amount

    def get_balance(self):
        return self.__balance


class PaymentPlugin(ABC):
    @abstractmethod
    def pay(self, amount):
        pass


class UPIPlugin(PaymentPlugin):
    def pay(self, amount):
        return "UPI payment successful"


class CardPlugin(PaymentPlugin):
    def pay(self, amount):
        return "Card payment successful"


class PaymentService:
    def __init__(self, account, payment_plugin):
        if not isinstance(payment_plugin,PaymentPlugin):
            raise TypeError("Invalid payment plugin")

        self.account=account
        self.payment_plugin=payment_plugin

    def make_payment(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        result=self.payment_plugin.pay(amount)
        self.account.withdraw(amount)

        return result


try:
    account=Account("ACC-1077",6000)
    payment_plugin=UPIPlugin()
    payment_service=PaymentService(account,payment_plugin)

    result=payment_service.make_payment(1500)

    print("Account:",account.account_number)
    print(result)
    print("Final balance:",account.get_balance())

except (TypeError,ValueError) as e:
    print("Payment failed:",e)
# Out:
# Account: ACC-1077
# UPI payment successful
# Final balance: 4500

# %% [markdown]
# ### Q78. Implement a descriptor for positive amounts for banking case 1; use sample reference `ACC-1078` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PositiveAmount:
    def __set_name__(self, owner, name):
        self.name="_"+name

    def __get__(self, instance, owner):
        if instance is None:
            return self
        return getattr(instance,self.name)

    def __set__(self, instance, value):
        if not isinstance(value,(int,float)):
            raise TypeError("Amount must be numeric")

        if value<=0:
            raise ValueError("Amount must be greater than zero")

        setattr(instance,self.name,value)


class Account:
    def __init__(self, account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        self.account_number=account_number
        self.balance=balance

    balance=PositiveAmount()

    def withdraw(self, amount):
        if amount>self.balance:
            raise ValueError("Insufficient balance")

        self.balance=self.balance-amount

    def show_details(self):
        print("Account:",self.account_number)
        print("Balance:",self.balance)


try:
    account=Account("ACC-1078",6000)
    account.withdraw(1500)
    account.show_details()

except (TypeError,ValueError) as e:
    print("Banking operation failed:",e)
# Out:
# Account: ACC-1078
# Balance: 4500

# %% [markdown]
# ### Q79. Use cooperative inheritance with super for banking case 1; use sample reference `ACC-1079` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance, **kwargs):
        super().__init__(**kwargs)

        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        self.account_number=account_number
        self.__balance=balance

    def get_balance(self):
        return self.__balance


class CustomerDetails:
    def __init__(self, customer_name, **kwargs):
        super().__init__(**kwargs)

        if not customer_name:
            raise ValueError("Customer name cannot be empty")

        self.customer_name=customer_name


class CustomerAccount(CustomerDetails,Account):
    def __init__(self, customer_name, account_number, balance):
        super().__init__(
            customer_name=customer_name,
            account_number=account_number,
            balance=balance
        )

    def show_details(self):
        print("Customer:",self.customer_name)
        print("Account:",self.account_number)
        print("Balance:",self.get_balance())


try:
    account=CustomerAccount("Ravi","ACC-1079",6000)
    account.show_details()

except (TypeError,ValueError) as e:
    print("Account creation failed:",e)
# Out:
# Customer: Ravi
# Account: ACC-1079
# Balance: 6000

# %% [markdown]
# ### Q80. Refactor a god object using solid for banking case 1; use sample reference `ACC-1080` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class AccountValidator:
    @staticmethod
    def validate(account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")


class Account:
    def __init__(self, account_number, balance):
        AccountValidator.validate(account_number,balance)

        self.account_number=account_number
        self.__balance=balance

    def withdraw(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance=self.__balance-amount

    def get_balance(self):
        return self.__balance


class AccountRepository:
    def __init__(self):
        self.accounts={}

    def save(self, account):
        self.accounts[account.account_number]=account

    def find(self, account_number):
        return self.accounts.get(account_number)


class TransactionService:
    def withdraw(self, account, amount):
        account.withdraw(amount)


class BankingService:
    def __init__(self, repository, transaction_service):
        self.repository=repository
        self.transaction_service=transaction_service

    def withdraw_money(self, account_number, amount):
        account=self.repository.find(account_number)

        if account is None:
            raise ValueError("Account not found")

        self.transaction_service.withdraw(account,amount)
        self.repository.save(account)

        return account.get_balance()


try:
    account=Account("ACC-1080",6000)

    repository=AccountRepository()
    repository.save(account)

    transaction_service=TransactionService()
    banking_service=BankingService(repository,transaction_service)

    final_balance=banking_service.withdraw_money("ACC-1080",1500)

    print("Account:",account.account_number)
    print("Final balance:",final_balance)

except (TypeError,ValueError) as e:
    print("Banking operation failed:",e)
# Out:
# Account: ACC-1080
# Final balance: 4500

# %% [markdown]
# ### Q81. Design an extensible pricing engine for banking case 2; use sample reference `ACC-1081` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PricingRule:
    def calculate(self, amount):
        raise NotImplementedError("Pricing rule must be implemented")


class RegularPricing(PricingRule):
    def calculate(self, amount):
        return amount


class PremiumPricing(PricingRule):
    def calculate(self, amount):
        return amount*0.85


class PricingEngine:
    def __init__(self, pricing_rule):
        if not isinstance(pricing_rule,PricingRule):
            raise TypeError("Invalid pricing rule")

        self.pricing_rule=pricing_rule

    def final_price(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        return self.pricing_rule.calculate(amount)


account="ACC-1081"
amount=8000

try:
    engine=PricingEngine(PremiumPricing())
    final_amount=engine.final_price(amount)

    print("Account:",account)
    print("Original amount:",amount)
    print("Final price:",final_amount)

except (TypeError,ValueError) as e:
    print("Pricing failed:",e)
# Out:
# Account: ACC-1081
# Original amount: 8000
# Final price: 6800.0

# %% [markdown]
# ### Q82. Implement an observer for low balance for banking case 2; use sample reference `ACC-1082` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class LowBalanceObserver:
    def update(self, account_number, balance):
        print("Alert:",account_number,"has low balance of",balance)


class Account:
    def __init__(self, account_number, balance, low_balance_limit):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        if not isinstance(low_balance_limit,(int,float)):
            raise TypeError("Low balance limit must be numeric")

        if low_balance_limit<0:
            raise ValueError("Low balance limit cannot be negative")

        self.account_number=account_number
        self.__balance=balance
        self.low_balance_limit=low_balance_limit
        self.observers=[]

    def add_observer(self, observer):
        self.observers.append(observer)

    def withdraw(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance=self.__balance-amount

        if self.__balance<=self.low_balance_limit:
            for observer in self.observers:
                observer.update(self.account_number,self.__balance)

    def show_balance(self):
        print("Account:",self.account_number)
        print("Final balance:",self.__balance)


try:
    account=Account("ACC-1082",8000,2500)
    observer=LowBalanceObserver()

    account.add_observer(observer)
    account.withdraw(6000)
    account.show_balance()

except (TypeError,ValueError) as e:
    print("Banking operation failed:",e)
# Out:
# Alert: ACC-1082 has low balance of 2000
# Account: ACC-1082
# Final balance: 2000

# %% [markdown]
# ### Q83. Build a state machine for transfer status for banking case 2; use sample reference `ACC-1083` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transfer:
    valid_states=["Pending","Processing","Completed","Failed"]

    def __init__(self, account, amount):
        if not account:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        self.account=account
        self.amount=amount
        self.status="Pending"

    def change_status(self, new_status):
        if new_status not in self.valid_states:
            raise ValueError("Invalid transfer status")

        allowed_transitions={
            "Pending":["Processing","Failed"],
            "Processing":["Completed","Failed"],
            "Completed":[],
            "Failed":[]
        }

        if new_status not in allowed_transitions[self.status]:
            raise ValueError("Invalid status transition")

        self.status=new_status

    def show_details(self):
        print("Account:",self.account)
        print("Transfer amount:",self.amount)
        print("Transfer status:",self.status)


try:
    transfer=Transfer("ACC-1083",5000)

    transfer.change_status("Processing")
    transfer.change_status("Completed")
    transfer.show_details()

except (TypeError,ValueError) as e:
    print("Transfer failed:",e)
# Out:
# Account: ACC-1083
# Transfer amount: 5000
# Transfer status: Completed

# %% [markdown]
# ### Q84. Create an immutable money value object for banking case 2; use sample reference `ACC-1084` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from dataclasses import dataclass
from decimal import Decimal

@dataclass(frozen=True)
class Money:
    amount: Decimal
    currency: str

    def __post_init__(self):
        if not isinstance(self.amount,Decimal):
            raise TypeError("Amount must be a Decimal")

        if self.amount<0:
            raise ValueError("Amount cannot be negative")

        if not self.currency:
            raise ValueError("Currency cannot be empty")

    def add(self, other):
        if self.currency!=other.currency:
            raise ValueError("Currencies must match")

        return Money(self.amount+other.amount,self.currency)


account="ACC-1084"

try:
    balance=Money(Decimal("8000.00"),"INR")
    deposit=Money(Decimal("2000.00"),"INR")
    final_balance=balance.add(deposit)

    print("Account:",account)
    print("Opening balance:",balance.amount,balance.currency)
    print("Deposit:",deposit.amount,deposit.currency)
    print("Final balance:",final_balance.amount,final_balance.currency)

except (TypeError,ValueError) as e:
    print("Money operation failed:",e)
# Out:
# Account: ACC-1084
# Opening balance: 8000.00 INR
# Deposit: 2000.00 INR
# Final balance: 10000.00 INR

# %% [markdown]
# ### Q85. Implement a unit-of-work transaction for banking case 2; use sample reference `ACC-1085` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        self.account_number=account_number
        self.__balance=balance

    def withdraw(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance=self.__balance-amount

    def deposit(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        self.__balance=self.__balance+amount

    def get_balance(self):
        return self.__balance


class UnitOfWork:
    def __init__(self, accounts):
        self.accounts=accounts
        self.old_balances={account.account_number:account.get_balance() for account in accounts}

    def __enter__(self):
        print("Transaction started")
        return self

    def __exit__(self, exc_type, exc_value, traceback):
        if exc_type:
            for account in self.accounts:
                account._Account__balance=self.old_balances[account.account_number]

            print("Transaction rolled back")
            print("Reason:",exc_value)
            return True

        print("Transaction committed")


try:
    account1=Account("ACC-1085",8000)
    account2=Account("ACC-2085",4000)

    with UnitOfWork([account1,account2]):
        account1.withdraw(3000)
        account2.deposit(3000)

    print("Account:",account1.account_number)
    print("Final balance:",account1.get_balance())
    print("Account:",account2.account_number)
    print("Final balance:",account2.get_balance())

except (TypeError,ValueError) as e:
    print("Transaction failed:",e)
# Out:
# Transaction started
# Transaction committed
# Account: ACC-1085
# Final balance: 5000
# Account: ACC-2085
# Final balance: 7000

# %% [markdown]
# ### Q86. Separate domain and infrastructure layers for banking case 2; use sample reference `ACC-1086` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        self.account_number=account_number
        self.__balance=balance

    def withdraw(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance=self.__balance-amount

    def get_balance(self):
        return self.__balance


class AccountRepository:
    def __init__(self):
        self.accounts={}

    def save(self, account):
        self.accounts[account.account_number]=account

    def find(self, account_number):
        return self.accounts.get(account_number)


class BankingService:
    def __init__(self, repository):
        self.repository=repository

    def withdraw_money(self, account_number, amount):
        account=self.repository.find(account_number)

        if account is None:
            raise ValueError("Account not found")

        account.withdraw(amount)
        self.repository.save(account)

        return account.get_balance()


try:
    account=Account("ACC-1086",8000)

    repository=AccountRepository()
    repository.save(account)

    service=BankingService(repository)
    final_balance=service.withdraw_money("ACC-1086",2500)

    print("Account:",account.account_number)
    print("Final balance:",final_balance)

except (TypeError,ValueError) as e:
    print("Banking operation failed:",e)
# Out:
# Account: ACC-1086
# Final balance: 5500

# %% [markdown]
# ### Q87. Design a plugin-ready payment architecture for banking case 2; use sample reference `ACC-1087` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from abc import ABC, abstractmethod

class Account:
    def __init__(self, account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        self.account_number=account_number
        self.__balance=balance

    def withdraw(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance=self.__balance-amount

    def get_balance(self):
        return self.__balance


class PaymentPlugin(ABC):
    @abstractmethod
    def pay(self, amount):
        pass


class UPIPlugin(PaymentPlugin):
    def pay(self, amount):
        return "UPI payment successful"


class CardPlugin(PaymentPlugin):
    def pay(self, amount):
        return "Card payment successful"


class PaymentService:
    def __init__(self, account, payment_plugin):
        if not isinstance(payment_plugin,PaymentPlugin):
            raise TypeError("Invalid payment plugin")

        self.account=account
        self.payment_plugin=payment_plugin

    def make_payment(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        result=self.payment_plugin.pay(amount)
        self.account.withdraw(amount)

        return result


try:
    account=Account("ACC-1087",8000)
    payment_plugin=CardPlugin()
    payment_service=PaymentService(account,payment_plugin)

    result=payment_service.make_payment(2500)

    print("Account:",account.account_number)
    print(result)
    print("Final balance:",account.get_balance())

except (TypeError,ValueError) as e:
    print("Payment failed:",e)
# Out:
# Account: ACC-1087
# Card payment successful
# Final balance: 5500

# %% [markdown]
# ### Q88. Implement a descriptor for positive amounts for banking case 2; use sample reference `ACC-1088` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PositiveAmount:
    def __set_name__(self, owner, name):
        self.name="_"+name

    def __get__(self, instance, owner):
        if instance is None:
            return self

        return getattr(instance,self.name)

    def __set__(self, instance, value):
        if not isinstance(value,(int,float)):
            raise TypeError("Amount must be numeric")

        if value<=0:
            raise ValueError("Amount must be greater than zero")

        setattr(instance,self.name,value)


class Account:
    balance=PositiveAmount()

    def __init__(self, account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        self.account_number=account_number
        self.balance=balance

    def withdraw(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>=self.balance:
            raise ValueError("Withdrawal must leave a positive balance")

        self.balance=self.balance-amount

    def show_details(self):
        print("Account:",self.account_number)
        print("Balance:",self.balance)


try:
    account=Account("ACC-1088",8000)
    account.withdraw(2500)
    account.show_details()

except (TypeError,ValueError) as e:
    print("Banking operation failed:",e)
# Out:
# Account: ACC-1088
# Balance: 5500

# %% [markdown]
# ### Q89. Use cooperative inheritance with super for banking case 2; use sample reference `ACC-1089` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance, **kwargs):
        super().__init__(**kwargs)

        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        self.account_number=account_number
        self.__balance=balance

    def get_balance(self):
        return self.__balance


class CustomerDetails:
    def __init__(self, customer_name, **kwargs):
        super().__init__(**kwargs)

        if not customer_name:
            raise ValueError("Customer name cannot be empty")

        self.customer_name=customer_name


class CustomerAccount(CustomerDetails,Account):
    def __init__(self, customer_name, account_number, balance):
        super().__init__(
            customer_name=customer_name,
            account_number=account_number,
            balance=balance
        )

    def show_details(self):
        print("Customer:",self.customer_name)
        print("Account:",self.account_number)
        print("Balance:",self.get_balance())


try:
    account=CustomerAccount("Anitha","ACC-1089",8000)
    account.show_details()

except (TypeError,ValueError) as e:
    print("Account creation failed:",e)
# Out:
# Customer: Anitha
# Account: ACC-1089
# Balance: 8000

# %% [markdown]
# ### Q90. Refactor a god object using solid for banking case 2; use sample reference `ACC-1090` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class AccountValidator:
    @staticmethod
    def validate(account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")


class Account:
    def __init__(self, account_number, balance):
        AccountValidator.validate(account_number,balance)

        self.account_number=account_number
        self.__balance=balance

    def withdraw(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance=self.__balance-amount

    def get_balance(self):
        return self.__balance


class AccountRepository:
    def __init__(self):
        self.accounts={}

    def save(self, account):
        self.accounts[account.account_number]=account

    def find(self, account_number):
        return self.accounts.get(account_number)


class TransactionService:
    def withdraw(self, account, amount):
        account.withdraw(amount)


class BankingService:
    def __init__(self, repository, transaction_service):
        self.repository=repository
        self.transaction_service=transaction_service

    def withdraw_money(self, account_number, amount):
        account=self.repository.find(account_number)

        if account is None:
            raise ValueError("Account not found")

        self.transaction_service.withdraw(account,amount)
        self.repository.save(account)

        return account.get_balance()


try:
    account=Account("ACC-1090",8000)

    repository=AccountRepository()
    repository.save(account)

    transaction_service=TransactionService()
    banking_service=BankingService(repository,transaction_service)

    final_balance=banking_service.withdraw_money("ACC-1090",2500)

    print("Account:",account.account_number)
    print("Final balance:",final_balance)

except (TypeError,ValueError) as e:
    print("Banking operation failed:",e)
# Out:
# Account: ACC-1090
# Final balance: 5500

# %% [markdown]
# ### Q91. Design an extensible pricing engine for banking case 3; use sample reference `ACC-1091` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PricingRule:
    def calculate(self, amount):
        raise NotImplementedError("Pricing rule must be implemented")


class RegularPricing(PricingRule):
    def calculate(self, amount):
        return amount


class PremiumPricing(PricingRule):
    def calculate(self, amount):
        return amount*0.80


class PricingEngine:
    def __init__(self, pricing_rule):
        if not isinstance(pricing_rule,PricingRule):
            raise TypeError("Invalid pricing rule")

        self.pricing_rule=pricing_rule

    def final_price(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        return self.pricing_rule.calculate(amount)


account="ACC-1091"
amount=10000

try:
    engine=PricingEngine(PremiumPricing())
    final_amount=engine.final_price(amount)

    print("Account:",account)
    print("Original amount:",amount)
    print("Final price:",final_amount)

except (TypeError,ValueError) as e:
    print("Pricing failed:",e)
# Out:
# Account: ACC-1091
# Original amount: 10000
# Final price: 8000.0

# %% [markdown]
# ### Q92. Implement an observer for low balance for banking case 3; use sample reference `ACC-1092` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class LowBalanceObserver:
    def update(self, account_number, balance):
        print("Alert:",account_number,"has low balance of",balance)


class Account:
    def __init__(self, account_number, balance, low_balance_limit):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        if not isinstance(low_balance_limit,(int,float)):
            raise TypeError("Low balance limit must be numeric")

        if low_balance_limit<0:
            raise ValueError("Low balance limit cannot be negative")

        self.account_number=account_number
        self.__balance=balance
        self.low_balance_limit=low_balance_limit
        self.observers=[]

    def add_observer(self, observer):
        self.observers.append(observer)

    def withdraw(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance=self.__balance-amount

        if self.__balance<=self.low_balance_limit:
            for observer in self.observers:
                observer.update(self.account_number,self.__balance)

    def show_balance(self):
        print("Account:",self.account_number)
        print("Final balance:",self.__balance)


try:
    account=Account("ACC-1092",10000,3000)
    observer=LowBalanceObserver()

    account.add_observer(observer)
    account.withdraw(7000)
    account.show_balance()

except (TypeError,ValueError) as e:
    print("Banking operation failed:",e)
# Out:
# Alert: ACC-1092 has low balance of 3000
# Account: ACC-1092
# Final balance: 3000

# %% [markdown]
# ### Q93. Build a state machine for transfer status for banking case 3; use sample reference `ACC-1093` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Transfer:
    valid_states=["Pending","Processing","Completed","Failed"]

    def __init__(self, account, amount):
        if not account:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        self.account=account
        self.amount=amount
        self.status="Pending"

    def change_status(self, new_status):
        if new_status not in self.valid_states:
            raise ValueError("Invalid transfer status")

        allowed_transitions={
            "Pending":["Processing","Failed"],
            "Processing":["Completed","Failed"],
            "Completed":[],
            "Failed":[]
        }

        if new_status not in allowed_transitions[self.status]:
            raise ValueError("Invalid status transition")

        self.status=new_status

    def show_details(self):
        print("Account:",self.account)
        print("Transfer amount:",self.amount)
        print("Transfer status:",self.status)


try:
    transfer=Transfer("ACC-1093",6000)

    transfer.change_status("Processing")
    transfer.change_status("Completed")
    transfer.show_details()

except (TypeError,ValueError) as e:
    print("Transfer failed:",e)
# Out:
# Account: ACC-1093
# Transfer amount: 6000
# Transfer status: Completed

# %% [markdown]
# ### Q94. Create an immutable money value object for banking case 3; use sample reference `ACC-1094` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from dataclasses import dataclass
from decimal import Decimal

@dataclass(frozen=True)
class Money:
    amount: Decimal
    currency: str

    def __post_init__(self):
        if not isinstance(self.amount,Decimal):
            raise TypeError("Amount must be a Decimal")

        if self.amount<0:
            raise ValueError("Amount cannot be negative")

        if not self.currency:
            raise ValueError("Currency cannot be empty")

    def add(self, other):
        if not isinstance(other,Money):
            raise TypeError("Other value must be Money")

        if self.currency!=other.currency:
            raise ValueError("Currencies must match")

        return Money(self.amount+other.amount,self.currency)


account="ACC-1094"

try:
    balance=Money(Decimal("10000.00"),"INR")
    deposit=Money(Decimal("3000.00"),"INR")
    final_balance=balance.add(deposit)

    print("Account:",account)
    print("Opening balance:",balance.amount,balance.currency)
    print("Deposit:",deposit.amount,deposit.currency)
    print("Final balance:",final_balance.amount,final_balance.currency)

except (TypeError,ValueError) as e:
    print("Money operation failed:",e)
# Out:
# Account: ACC-1094
# Opening balance: 10000.00 INR
# Deposit: 3000.00 INR
# Final balance: 13000.00 INR

# %% [markdown]
# ### Q95. Implement a unit-of-work transaction for banking case 3; use sample reference `ACC-1095` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        self.account_number=account_number
        self.__balance=balance

    def withdraw(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance=self.__balance-amount

    def deposit(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        self.__balance=self.__balance+amount

    def get_balance(self):
        return self.__balance


class UnitOfWork:
    def __init__(self, accounts):
        self.accounts=accounts
        self.old_balances={account.account_number:account.get_balance() for account in accounts}

    def __enter__(self):
        print("Transaction started")
        return self

    def __exit__(self, exc_type, exc_value, traceback):
        if exc_type:
            for account in self.accounts:
                account._Account__balance=self.old_balances[account.account_number]

            print("Transaction rolled back")
            print("Reason:",exc_value)
            return True

        print("Transaction committed")


try:
    account1=Account("ACC-1095",10000)
    account2=Account("ACC-2095",5000)

    with UnitOfWork([account1,account2]):
        account1.withdraw(4000)
        account2.deposit(4000)

    print("Account:",account1.account_number)
    print("Final balance:",account1.get_balance())
    print("Account:",account2.account_number)
    print("Final balance:",account2.get_balance())

except (TypeError,ValueError) as e:
    print("Transaction failed:",e)
# Out:
# Transaction started
# Transaction committed
# Account: ACC-1095
# Final balance: 6000
# Account: ACC-2095
# Final balance: 9000

# %% [markdown]
# ### Q96. Separate domain and infrastructure layers for banking case 3; use sample reference `ACC-1096` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        self.account_number=account_number
        self.__balance=balance

    def withdraw(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance=self.__balance-amount

    def get_balance(self):
        return self.__balance


class AccountRepository:
    def __init__(self):
        self.accounts={}

    def save(self, account):
        self.accounts[account.account_number]=account

    def find(self, account_number):
        return self.accounts.get(account_number)


class BankingService:
    def __init__(self, repository):
        self.repository=repository

    def withdraw_money(self, account_number, amount):
        account=self.repository.find(account_number)

        if account is None:
            raise ValueError("Account not found")

        account.withdraw(amount)
        self.repository.save(account)

        return account.get_balance()


try:
    account=Account("ACC-1096",10000)

    repository=AccountRepository()
    repository.save(account)

    service=BankingService(repository)
    final_balance=service.withdraw_money("ACC-1096",3000)

    print("Account:",account.account_number)
    print("Final balance:",final_balance)

except (TypeError,ValueError) as e:
    print("Banking operation failed:",e)
# Out:
# Account: ACC-1096
# Final balance: 7000

# %% [markdown]
# ### Q97. Design a plugin-ready payment architecture for banking case 3; use sample reference `ACC-1097` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
from abc import ABC, abstractmethod


class Account:
    def __init__(self, account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        self.account_number=account_number
        self.__balance=balance

    def withdraw(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance=self.__balance-amount

    def get_balance(self):
        return self.__balance


class PaymentPlugin(ABC):
    @abstractmethod
    def pay(self, amount):
        pass


class UPIPlugin(PaymentPlugin):
    def pay(self, amount):
        return "UPI payment successful: " + str(amount)


class CardPlugin(PaymentPlugin):
    def pay(self, amount):
        return "Card payment successful: " + str(amount)


class NetBankingPlugin(PaymentPlugin):
    def pay(self, amount):
        return "Net banking payment successful: " + str(amount)


class PaymentService:
    def __init__(self, account, payment_plugin):
        self.account=account
        self.payment_plugin=payment_plugin

    def make_payment(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>self.account.get_balance():
            raise ValueError("Insufficient balance")

        result=self.payment_plugin.pay(amount)
        self.account.withdraw(amount)

        return result


try:
    account=Account("ACC-1097",10000)

    payment_plugin=UPIPlugin()
    payment_service=PaymentService(account,payment_plugin)

    result=payment_service.make_payment(3000)

    print("Account:",account.account_number)
    print(result)
    print("Final balance:",account.get_balance())

except (TypeError,ValueError) as e:
    print("Payment failed:",e)
# Out:
# Account: ACC-1097
# UPI payment successful: 3000
# Final balance: 7000

# %% [markdown]
# ### Q98. Implement a descriptor for positive amounts for banking case 3; use sample reference `ACC-1098` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class PositiveAmount:
    def __set_name__(self, owner, name):
        self.name="_" + name

    def __get__(self, instance, owner):
        if instance is None:
            return self
        return getattr(instance,self.name)

    def __set__(self, instance, value):
        if not isinstance(value,(int,float)):
            raise TypeError("Amount must be numeric")

        if value<=0:
            raise ValueError("Amount must be greater than zero")

        setattr(instance,self.name,value)


class Account:
    balance=PositiveAmount()

    def __init__(self, account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        self.account_number=account_number
        self.balance=balance

    def deposit(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        self.balance=self.balance+amount

    def withdraw(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>self.balance:
            raise ValueError("Insufficient balance")

        self.balance=self.balance-amount

    def get_balance(self):
        return self.balance


try:
    account=Account("ACC-1098",10000)

    account.deposit(2000)
    account.withdraw(3000)

    print("Account:",account.account_number)
    print("Final balance:",account.get_balance())

except (TypeError,ValueError) as e:
    print("Banking operation failed:",e)
# Out:
# Account: ACC-1098
# Final balance: 9000

# %% [markdown]
# ### Q99. Use cooperative inheritance with super for banking case 3; use sample reference `ACC-1099` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Customer:
    def __init__(self, name, **kwargs):
        if not name:
            raise ValueError("Customer name cannot be empty")

        self.name=name
        super().__init__(**kwargs)


class Account:
    def __init__(self, account_number, balance, **kwargs):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        self.account_number=account_number
        self.__balance=balance
        super().__init__(**kwargs)

    def deposit(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        self.__balance=self.__balance+amount

    def withdraw(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance=self.__balance-amount

    def get_balance(self):
        return self.__balance


class SavingsAccount(Customer,Account):
    def __init__(self, name, account_number, balance):
        super().__init__(name=name,account_number=account_number,balance=balance)


try:
    account=SavingsAccount("Ravi","ACC-1099",10000)

    account.deposit(2000)
    account.withdraw(3000)

    print("Customer:",account.name)
    print("Account:",account.account_number)
    print("Final balance:",account.get_balance())

except (TypeError,ValueError) as e:
    print("Account operation failed:",e)
# Out:
# Customer: Ravi
# Account: ACC-1099
# Final balance: 9000

# %% [markdown]
# ### Q100. Refactor a god object using solid for banking case 3; use sample reference `ACC-1100` and explain the result.
#
# **Hints**
#
# 1. List the objects, their responsibilities, and their invariants before coding.
# 2. Choose composition for has-a relationships; use inheritance only for genuine is-a substitution.
# 3. Keep balances private and expose controlled deposit/withdraw/transfer behavior.
#
# **Edge cases to test:** empty input, invalid types, boundary values, and a realistic failure path.

# %%
class Account:
    def __init__(self, account_number, balance):
        if not account_number:
            raise ValueError("Account reference cannot be empty")

        if not isinstance(balance,(int,float)):
            raise TypeError("Balance must be numeric")

        if balance<0:
            raise ValueError("Balance cannot be negative")

        self.account_number=account_number
        self.__balance=balance

    def deposit(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        self.__balance=self.__balance+amount

    def withdraw(self, amount):
        if not isinstance(amount,(int,float)):
            raise TypeError("Amount must be numeric")

        if amount<=0:
            raise ValueError("Amount must be greater than zero")

        if amount>self.__balance:
            raise ValueError("Insufficient balance")

        self.__balance=self.__balance-amount

    def get_balance(self):
        return self.__balance


class AccountRepository:
    def __init__(self):
        self.accounts={}

    def save(self, account):
        self.accounts[account.account_number]=account

    def find(self, account_number):
        return self.accounts.get(account_number)


class AccountStatement:
    def show(self, account):
        print("Account:",account.account_number)
        print("Balance:",account.get_balance())


class BankingService:
    def __init__(self, repository, statement):
        self.repository=repository
        self.statement=statement

    def deposit_money(self, account_number, amount):
        account=self.repository.find(account_number)

        if account is None:
            raise ValueError("Account not found")

        account.deposit(amount)
        self.repository.save(account)

    def withdraw_money(self, account_number, amount):
        account=self.repository.find(account_number)

        if account is None:
            raise ValueError("Account not found")

        account.withdraw(amount)
        self.repository.save(account)

    def show_account(self, account_number):
        account=self.repository.find(account_number)

        if account is None:
            raise ValueError("Account not found")

        self.statement.show(account)


try:
    account=Account("ACC-1100",10000)

    repository=AccountRepository()
    repository.save(account)

    statement=AccountStatement()
    service=BankingService(repository,statement)

    service.deposit_money("ACC-1100",2000)
    service.withdraw_money("ACC-1100",3000)
    service.show_account("ACC-1100")

except (TypeError,ValueError) as e:
    print("Banking operation failed:",e)
# Out:
# Account: ACC-1100
# Balance: 9000
